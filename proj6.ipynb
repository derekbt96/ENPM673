# %% [markdown]
# <a href="https://colab.research.google.com/github/derekbt96/ENPM673/blob/master/proj6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

zip_ref = zipfile.ZipFile("/content/drive/My Drive/Copy of dogs-vs-cats.zip", 'r')
zip_ref.extractall("/tmp")
zip_ref.close()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
zip_ref = zipfile.ZipFile("/tmp/train.zip", 'r')
zip_ref.extractall("/content/dataset/")
zip_ref.close()

# %%
# !mkdir /content/train_renamed
# Out:
# mkdir: cannot create directory ‘/content/train_renamed’: File exists

# %%
import cv2
import numpy as np
import os
import math

snc = 0
snd = 12500
# PATH = './train'
# for file in sorted(os.listdir(PATH)):
#     filepath = os.path.join(PATH,file)
#     if filepath.endswith(".jpg") or filepath.endswith(".pgm") or filepath.endswith(".png") or filepath.endswith(".ppm"):
for subdir, dirs, files in os.walk('/content/dataset/train'):
        for file in files:
            filepath = subdir + os.sep + file
            if filepath.endswith(".jpg") or filepath.endswith(".pgm") or filepath.endswith(".png") or filepath.endswith(".ppm"):
            # print(filepath)
                img = cv2.imread(filepath)
                img1 = img.copy()

                if "cat" in filepath:
                    print("Filepath {} has cat".format(filepath))
                    sss = "/content/train_renamed/{0}.png".format(snc)
                    cv2.imwrite(sss,img)
                    snc = snc+1

                elif "dog" in filepath:
                    print("Filepath {} has dog".format(filepath))
                    sss = "/content/train_renamed/{0}.png".format(snd)
                    cv2.imwrite(sss,img)
                    snd = snd+1


print(snc, snd)
# Out:
# Streaming output truncated to the last 5000 lines.
# Filepath /content/dataset/train/dog.3752.jpg has dog
# Filepath /content/dataset/train/dog.10208.jpg has dog
# Filepath /content/dataset/train/dog.284.jpg has dog
# Filepath /content/dataset/train/cat.2333.jpg has cat
# Filepath /content/dataset/train/dog.2359.jpg has dog
# Filepath /content/dataset/train/dog.7869.jpg has dog
# Filepath /content/dataset/train/cat.9642.jpg has cat
# Filepath /content/dataset/train/cat.6032.jpg has cat
# Filepath /content/dataset/train/dog.834.jpg has dog
# Filepath /content/dataset/train/dog.884.jpg has dog
# Filepath /content/dataset/train/cat.109.jpg has cat
# Filepath /content/dataset/train/cat.3586.jpg has cat
# Filepath /content/dataset/train/dog.5595.jpg has dog
# Filepath /content/dataset/train/dog.5238.jpg has dog
# Filepath /content/dataset/train/cat.4524.jpg has cat
# Filepath /content/dataset/train/dog.2240.jpg has dog
# Filepath /content/dataset/train/dog.11088.jpg has dog
# Filepath /content/dataset/train/dog.1181.jpg has dog
# Filepath /content/dataset/train/dog.6976.jpg has dog
# Filepath /content/dataset/train/cat.11491.jpg has cat
# Filepath /content/dataset/train/cat.6675.jpg has cat
# Filepath /content/dataset/train/dog.3144.jpg has dog
# Filepath /content/dataset/train/dog.1361.jpg has dog
# Filepath /content/dataset/train/dog.11512.jpg has dog
# Filepath /content/dataset/train/dog.7417.jpg has dog
# Filepath /content/dataset/train/cat.9651.jpg has cat
# Filepath /content/dataset/train/dog.2763.jpg has dog
# Filepath /content/dataset/train/dog.2078.jpg has dog
# Filepath /content/dataset/train/dog.11062.jpg has dog
# Filepath /content/dataset/train/cat.10153.jpg has cat
# Filepath /content/dataset/train/cat.11427.jpg has cat
# Filepath /content/dataset/train/cat.6112.jpg has cat
# Filepath /content/dataset/train/dog.4380.jpg has dog
# Filepath /content/dataset/train/cat.1743.jpg has cat
# Filepath /content/dataset/train/dog.2400.jpg has dog
# Filepath /content/dataset/train/dog.7856.jpg has dog
# Filepath /content/dataset/train/cat.8963.jpg has cat
# Filepath /content/dataset/train/dog.5221.jpg has dog
# Filepath /content/dataset/train/cat.6913.jpg has cat
# Filepath /content/dataset/train/dog.11450.jpg has dog
# Filepath /content/dataset/train/dog.11692.jpg has dog
# Filepath /content/dataset/train/dog.11215.jpg has dog
# Filepath /content/dataset/train/cat.5774.jpg has cat
# Filepath /content/dataset/train/cat.4883.jpg has cat
# Filepath /content/dataset/train/cat.2447.jpg has cat
# Filepath /content/dataset/train/dog.8433.jpg has dog
# Filepath /content/dataset/train/cat.9887.jpg has cat
# Filepath /content/dataset/train/cat.5795.jpg has cat
# Filepath /content/dataset/train/cat.3318.jpg has cat
# Filepath /content/dataset/train/cat.5860.jpg has cat
# Filepath /content/dataset/train/cat.1917.jpg has cat
# Filepath /content/dataset/train/dog.10207.jpg has dog
# Filepath /content/dataset/train/cat.159.jpg has cat
# Filepath /content/dataset/train/dog.4514.jpg has dog
# Filepath /content/dataset/train/dog.11981.jpg has dog
# Filepath /content/dataset/train/cat.9888.jpg has cat
# Filepath /content/dataset/train/cat.12492.jpg has cat
# Filepath /content/dataset/train/cat.6402.jpg has cat
# Filepath /content/dataset/train/cat.9831.jpg has cat
# Filepath /content/dataset/train/dog.5375.jpg has dog
# Filepath /content/dataset/train/cat.6537.jpg has cat
# Filepath /content/dataset/train/dog.2995.jpg has dog
# Filepath /content/dataset/train/dog.11022.jpg has dog
# Filepath /content/dataset/train/cat.3010.jpg has cat
# Filepath /content/dataset/train/cat.8348.jpg has cat
# Filepath /content/dataset/train/cat.9152.jpg has cat
# Filepath /content/dataset/train/cat.1634.jpg has cat
# Filepath /content/dataset/train/dog.5707.jpg has dog
# Filepath /content/dataset/train/dog.9072.jpg has dog
# Filepath /content/dataset/train/cat.11829.jpg has cat
# Filepath /content/dataset/train/dog.2958.jpg has dog
# Filepath /content/dataset/train/cat.1688.jpg has cat
# Filepath /content/dataset/train/cat.4855.jpg has cat
# Filepath /content/dataset/train/dog.3799.jpg has dog
# Filepath /content/dataset/train/dog.3763.jpg has dog
# Filepath /content/dataset/train/dog.6392.jpg has dog
# Filepath /content/dataset/train/cat.10636.jpg has cat
# Filepath /content/dataset/train/cat.3000.jpg has cat
# Filepath /content/dataset/train/dog.4915.jpg has dog
# Filepath /content/dataset/train/dog.11146.jpg has dog
# Filepath /content/dataset/train/cat.3918.jpg has cat
# Filepath /content/dataset/train/cat.12477.jpg has cat
# Filepath /content/dataset/train/cat.10639.jpg has cat
# Filepath /content/dataset/train/cat.6994.jpg has cat
# Filepath /content/dataset/train/cat.2412.jpg has cat
# Filepath /content/dataset/train/cat.4873.jpg has cat
# Filepath /content/dataset/train/cat.9303.jpg has cat
# Filepath /content/dataset/train/cat.3406.jpg has cat
# Filepath /content/dataset/train/cat.2540.jpg has cat
# Filepath /content/dataset/train/cat.7301.jpg has cat
# Filepath /content/dataset/train/cat.575.jpg has cat
# Filepath /content/dataset/train/cat.8667.jpg has cat
# Filepath /content/dataset/train/dog.10663.jpg has dog
# Filepath /content/dataset/train/cat.6232.jpg has cat
# Filepath /content/dataset/train/dog.10321.jpg has dog
# Filepath /content/dataset/train/cat.7881.jpg has cat
# Filepath /content/dataset/train/dog.10201.jpg has dog
# Filepath /content/dataset/train/dog.12286.jpg has dog
# Filepath /content/dataset/train/cat.1673.jpg has cat
# Filepath /content/dataset/train/cat.11853.jpg has cat
# Filepath /content/dataset/train/cat.8234.jpg has cat
# Filepath /content/dataset/train/dog.4430.jpg has dog
# Filepath /content/dataset/train/cat.10398.jpg has cat
# Filepath /content/dataset/train/dog.11507.jpg has dog
# Filepath /content/dataset/train/cat.5184.jpg has cat
# Filepath /content/dataset/train/cat.9727.jpg has cat
# Filepath /content/dataset/train/cat.164.jpg has cat
# Filepath /content/dataset/train/dog.5357.jpg has dog
# Filepath /content/dataset/train/dog.11539.jpg has dog
# Filepath /content/dataset/train/cat.6235.jpg has cat
# Filepath /content/dataset/train/dog.12356.jpg has dog
# Filepath /content/dataset/train/cat.10951.jpg has cat
# Filepath /content/dataset/train/cat.10293.jpg has cat
# Filepath /content/dataset/train/cat.4221.jpg has cat
# Filepath /content/dataset/train/dog.745.jpg has dog
# Filepath /content/dataset/train/dog.1862.jpg has dog
# Filepath /content/dataset/train/cat.8663.jpg has cat
# Filepath /content/dataset/train/cat.9663.jpg has cat
# Filepath /content/dataset/train/cat.4214.jpg has cat
# Filepath /content/dataset/train/dog.11700.jpg has dog
# Filepath /content/dataset/train/cat.3663.jpg has cat
# Filepath /content/dataset/train/dog.10195.jpg has dog
# Filepath /content/dataset/train/cat.10115.jpg has cat
# Filepath /content/dataset/train/dog.4591.jpg has dog
# Filepath /content/dataset/train/cat.12203.jpg has cat
# Filepath /content/dataset/train/dog.3545.jpg has dog
# Filepath /content/dataset/train/dog.6234.jpg has dog
# Filepath /content/dataset/train/dog.5209.jpg has dog
# Filepath /content/dataset/train/cat.635.jpg has cat
# Filepath /content/dataset/train/cat.3708.jpg has cat
# Filepath /content/dataset/train/dog.4118.jpg has dog
# Filepath /content/dataset/train/cat.6079.jpg has cat
# Filepath /content/dataset/train/cat.6350.jpg has cat
# Filepath /content/dataset/train/dog.1055.jpg has dog
# Filepath /content/dataset/train/cat.9667.jpg has cat
# Filepath /content/dataset/train/cat.7270.jpg has cat
# Filepath /content/dataset/train/cat.8138.jpg has cat
# Filepath /content/dataset/train/dog.4466.jpg has dog
# Filepath /content/dataset/train/cat.5576.jpg has cat
# Filepath /content/dataset/train/cat.11545.jpg has cat
# Filepath /content/dataset/train/dog.10395.jpg has dog
# Filepath /content/dataset/train/dog.8033.jpg has dog
# Filepath /content/dataset/train/cat.8135.jpg has cat
# Filepath /content/dataset/train/dog.1374.jpg has dog
# Filepath /content/dataset/train/cat.5140.jpg has cat
# Filepath /content/dataset/train/cat.7761.jpg has cat
# Filepath /content/dataset/train/dog.9555.jpg has dog
# Filepath /content/dataset/train/cat.4584.jpg has cat
# Filepath /content/dataset/train/dog.3137.jpg has dog
# Filepath /content/dataset/train/cat.392.jpg has cat
# Filepath /content/dataset/train/cat.7898.jpg has cat
# Filepath /content/dataset/train/cat.6226.jpg has cat
# Filepath /content/dataset/train/cat.478.jpg has cat
# Filepath /content/dataset/train/cat.11320.jpg has cat
# Filepath /content/dataset/train/cat.2978.jpg has cat
# Filepath /content/dataset/train/dog.3097.jpg has dog
# Filepath /content/dataset/train/cat.5492.jpg has cat
# Filepath /content/dataset/train/cat.10124.jpg has cat
# Filepath /content/dataset/train/dog.3361.jpg has dog
# Filepath /content/dataset/train/cat.3991.jpg has cat
# Filepath /content/dataset/train/dog.2184.jpg has dog
# Filepath /content/dataset/train/cat.8083.jpg has cat
# Filepath /content/dataset/train/cat.4372.jpg has cat
# Filepath /content/dataset/train/dog.6502.jpg has dog
# Filepath /content/dataset/train/dog.6376.jpg has dog
# Filepath /content/dataset/train/dog.4539.jpg has dog
# Filepath /content/dataset/train/dog.7549.jpg has dog
# Filepath /content/dataset/train/cat.6376.jpg has cat
# Filepath /content/dataset/train/dog.5147.jpg has dog
# Filepath /content/dataset/train/cat.12294.jpg has cat
# Filepath /content/dataset/train/cat.11318.jpg has cat
# Filepath /content/dataset/train/dog.589.jpg has dog
# Filepath /content/dataset/train/cat.1458.jpg has cat
# Filepath /content/dataset/train/cat.549.jpg has cat
# Filepath /content/dataset/train/cat.5683.jpg has cat
# Filepath /content/dataset/train/dog.876.jpg has dog
# Filepath /content/dataset/train/dog.11189.jpg has dog
# Filepath /content/dataset/train/cat.6403.jpg has cat
# Filepath /content/dataset/train/dog.3527.jpg has dog
# Filepath /content/dataset/train/dog.623.jpg has dog
# Filepath /content/dataset/train/dog.5340.jpg has dog
# Filepath /content/dataset/train/cat.10494.jpg has cat
# Filepath /content/dataset/train/dog.3474.jpg has dog
# Filepath /content/dataset/train/dog.1948.jpg has dog
# Filepath /content/dataset/train/dog.6243.jpg has dog
# Filepath /content/dataset/train/cat.12175.jpg has cat
# Filepath /content/dataset/train/dog.2181.jpg has dog
# Filepath /content/dataset/train/cat.1727.jpg has cat
# Filepath /content/dataset/train/cat.4643.jpg has cat
# Filepath /content/dataset/train/dog.4951.jpg has dog
# Filepath /content/dataset/train/cat.1294.jpg has cat
# Filepath /content/dataset/train/dog.10150.jpg has dog
# Filepath /content/dataset/train/dog.2476.jpg has dog
# Filepath /content/dataset/train/dog.10034.jpg has dog
# Filepath /content/dataset/train/cat.11700.jpg has cat
# Filepath /content/dataset/train/cat.9338.jpg has cat
# Filepath /content/dataset/train/cat.8071.jpg has cat
# Filepath /content/dataset/train/dog.9813.jpg has dog
# Filepath /content/dataset/train/dog.1440.jpg has dog
# Filepath /content/dataset/train/dog.2816.jpg has dog
# Filepath /content/dataset/train/cat.2647.jpg has cat
# Filepath /content/dataset/train/cat.5051.jpg has cat
# Filepath /content/dataset/train/dog.9376.jpg has dog
# Filepath /content/dataset/train/cat.3105.jpg has cat
# Filepath /content/dataset/train/dog.6419.jpg has dog
# Filepath /content/dataset/train/cat.9590.jpg has cat
# Filepath /content/dataset/train/dog.9281.jpg has dog
# Filepath /content/dataset/train/cat.7156.jpg has cat
# Filepath /content/dataset/train/dog.8015.jpg has dog
# Filepath /content/dataset/train/cat.476.jpg has cat
# Filepath /content/dataset/train/dog.8521.jpg has dog
# Filepath /content/dataset/train/dog.2389.jpg has dog
# Filepath /content/dataset/train/cat.6440.jpg has cat
# Filepath /content/dataset/train/dog.9815.jpg has dog
# Filepath /content/dataset/train/dog.3290.jpg has dog
# Filepath /content/dataset/train/cat.8793.jpg has cat
# Filepath /content/dataset/train/cat.7938.jpg has cat
# Filepath /content/dataset/train/cat.8840.jpg has cat
# Filepath /content/dataset/train/dog.4588.jpg has dog
# Filepath /content/dataset/train/cat.11273.jpg has cat
# Filepath /content/dataset/train/cat.6503.jpg has cat
# Filepath /content/dataset/train/dog.4370.jpg has dog
# Filepath /content/dataset/train/cat.3589.jpg has cat
# Filepath /content/dataset/train/dog.1669.jpg has dog
# Filepath /content/dataset/train/cat.3485.jpg has cat
# Filepath /content/dataset/train/cat.4367.jpg has cat
# Filepath /content/dataset/train/dog.2309.jpg has dog
# Filepath /content/dataset/train/cat.7670.jpg has cat
# Filepath /content/dataset/train/cat.5867.jpg has cat
# Filepath /content/dataset/train/cat.1344.jpg has cat
# Filepath /content/dataset/train/dog.11916.jpg has dog
# Filepath /content/dataset/train/dog.46.jpg has dog
# Filepath /content/dataset/train/dog.675.jpg has dog
# Filepath /content/dataset/train/cat.822.jpg has cat
# Filepath /content/dataset/train/dog.6120.jpg has dog
# Filepath /content/dataset/train/cat.2018.jpg has cat
# Filepath /content/dataset/train/cat.9431.jpg has cat
# Filepath /content/dataset/train/cat.9080.jpg has cat
# Filepath /content/dataset/train/dog.466.jpg has dog
# Filepath /content/dataset/train/dog.6728.jpg has dog
# Filepath /content/dataset/train/dog.7842.jpg has dog
# Filepath /content/dataset/train/dog.6640.jpg has dog
# Filepath /content/dataset/train/dog.960.jpg has dog
# Filepath /content/dataset/train/cat.8293.jpg has cat
# Filepath /content/dataset/train/dog.8072.jpg has dog
# Filepath /content/dataset/train/dog.1395.jpg has dog
# Filepath /content/dataset/train/dog.5876.jpg has dog
# Filepath /content/dataset/train/dog.2117.jpg has dog
# Filepath /content/dataset/train/cat.4494.jpg has cat
# Filepath /content/dataset/train/dog.3053.jpg has dog
# Filepath /content/dataset/train/dog.11300.jpg has dog
# Filepath /content/dataset/train/cat.2319.jpg has cat
# Filepath /content/dataset/train/dog.11853.jpg has dog
# Filepath /content/dataset/train/dog.10231.jpg has dog
# Filepath /content/dataset/train/cat.9924.jpg has cat
# Filepath /content/dataset/train/cat.3061.jpg has cat
# Filepath /content/dataset/train/cat.12361.jpg has cat
# Filepath /content/dataset/train/dog.4555.jpg has dog
# Filepath /content/dataset/train/dog.4239.jpg has dog
# Filepath /content/dataset/train/dog.3076.jpg has dog
# Filepath /content/dataset/train/cat.6099.jpg has cat
# Filepath /content/dataset/train/dog.8469.jpg has dog
# Filepath /content/dataset/train/dog.12065.jpg has dog
# Filepath /content/dataset/train/dog.263.jpg has dog
# Filepath /content/dataset/train/cat.7411.jpg has cat
# Filepath /content/dataset/train/dog.312.jpg has dog
# Filepath /content/dataset/train/cat.4207.jpg has cat
# Filepath /content/dataset/train/cat.10628.jpg has cat
# Filepath /content/dataset/train/dog.343.jpg has dog
# Filepath /content/dataset/train/cat.8930.jpg has cat
# Filepath /content/dataset/train/cat.2923.jpg has cat
# Filepath /content/dataset/train/cat.7973.jpg has cat
# Filepath /content/dataset/train/dog.7973.jpg has dog
# Filepath /content/dataset/train/cat.1323.jpg has cat
# Filepath /content/dataset/train/dog.4957.jpg has dog
# Filepath /content/dataset/train/dog.1288.jpg has dog
# Filepath /content/dataset/train/dog.2151.jpg has dog
# Filepath /content/dataset/train/dog.8439.jpg has dog
# Filepath /content/dataset/train/dog.4406.jpg has dog
# Filepath /content/dataset/train/dog.10849.jpg has dog
# Filepath /content/dataset/train/cat.1304.jpg has cat
# Filepath /content/dataset/train/dog.5852.jpg has dog
# Filepath /content/dataset/train/cat.1807.jpg has cat
# Filepath /content/dataset/train/cat.1365.jpg has cat
# Filepath /content/dataset/train/cat.4120.jpg has cat
# Filepath /content/dataset/train/cat.9671.jpg has cat
# Filepath /content/dataset/train/dog.3054.jpg has dog
# Filepath /content/dataset/train/dog.11253.jpg has dog
# Filepath /content/dataset/train/dog.2136.jpg has dog
# Filepath /content/dataset/train/dog.582.jpg has dog
# Filepath /content/dataset/train/cat.5319.jpg has cat
# Filepath /content/dataset/train/dog.7115.jpg has dog
# Filepath /content/dataset/train/cat.4770.jpg has cat
# Filepath /content/dataset/train/dog.3273.jpg has dog
# Filepath /content/dataset/train/dog.1801.jpg has dog
# Filepath /content/dataset/train/cat.1741.jpg has cat
# Filepath /content/dataset/train/cat.8527.jpg has cat
# Filepath /content/dataset/train/dog.2665.jpg has dog
# Filepath /content/dataset/train/dog.6135.jpg has dog
# Filepath /content/dataset/train/cat.7002.jpg has cat
# Filepath /content/dataset/train/dog.3881.jpg has dog
# Filepath /content/dataset/train/cat.6260.jpg has cat
# Filepath /content/dataset/train/cat.10606.jpg has cat
# Filepath /content/dataset/train/cat.7867.jpg has cat
# Filepath /content/dataset/train/dog.4873.jpg has dog
# Filepath /content/dataset/train/dog.9019.jpg has dog
# Filepath /content/dataset/train/dog.12230.jpg has dog
# Filepath /content/dataset/train/dog.7514.jpg has dog
# Filepath /content/dataset/train/dog.10326.jpg has dog
# Filepath /content/dataset/train/dog.4621.jpg has dog
# Filepath /content/dataset/train/dog.12212.jpg has dog
# Filepath /content/dataset/train/cat.3552.jpg has cat
# Filepath /content/dataset/train/cat.4324.jpg has cat
# Filepath /content/dataset/train/cat.1766.jpg has cat
# Filepath /content/dataset/train/cat.5102.jpg has cat
# Filepath /content/dataset/train/cat.4274.jpg has cat
# Filepath /content/dataset/train/dog.8896.jpg has dog
# Filepath /content/dataset/train/dog.12131.jpg has dog
# Filepath /content/dataset/train/dog.4666.jpg has dog
# Filepath /content/dataset/train/dog.2411.jpg has dog
# Filepath /content/dataset/train/dog.2258.jpg has dog
# Filepath /content/dataset/train/dog.1073.jpg has dog
# Filepath /content/dataset/train/cat.8937.jpg has cat
# Filepath /content/dataset/train/dog.8161.jpg has dog
# Filepath /content/dataset/train/cat.1869.jpg has cat
# Filepath /content/dataset/train/cat.955.jpg has cat
# Filepath /content/dataset/train/dog.3863.jpg has dog
# Filepath /content/dataset/train/cat.2585.jpg has cat
# Filepath /content/dataset/train/cat.10518.jpg has cat
# Filepath /content/dataset/train/dog.1070.jpg has dog
# Filepath /content/dataset/train/dog.1912.jpg has dog
# Filepath /content/dataset/train/dog.8778.jpg has dog
# Filepath /content/dataset/train/dog.535.jpg has dog
# Filepath /content/dataset/train/cat.7600.jpg has cat
# Filepath /content/dataset/train/dog.4680.jpg has dog
# Filepath /content/dataset/train/dog.11045.jpg has dog
# Filepath /content/dataset/train/cat.1656.jpg has cat
# Filepath /content/dataset/train/dog.6641.jpg has dog
# Filepath /content/dataset/train/cat.12009.jpg has cat
# Filepath /content/dataset/train/dog.7888.jpg has dog
# Filepath /content/dataset/train/dog.5462.jpg has dog
# Filepath /content/dataset/train/cat.5976.jpg has cat
# Filepath /content/dataset/train/cat.10706.jpg has cat
# Filepath /content/dataset/train/cat.3639.jpg has cat
# Filepath /content/dataset/train/dog.1752.jpg has dog
# Filepath /content/dataset/train/dog.12066.jpg has dog
# Filepath /content/dataset/train/dog.3395.jpg has dog
# Filepath /content/dataset/train/cat.11466.jpg has cat
# Filepath /content/dataset/train/cat.11580.jpg has cat
# Filepath /content/dataset/train/dog.2320.jpg has dog
# Filepath /content/dataset/train/cat.5798.jpg has cat
# Filepath /content/dataset/train/dog.10762.jpg has dog
# Filepath /content/dataset/train/dog.12231.jpg has dog
# Filepath /content/dataset/train/cat.2223.jpg has cat
# Filepath /content/dataset/train/dog.6142.jpg has dog
# Filepath /content/dataset/train/cat.10377.jpg has cat
# Filepath /content/dataset/train/dog.4222.jpg has dog
# Filepath /content/dataset/train/cat.6295.jpg has cat
# Filepath /content/dataset/train/dog.7074.jpg has dog
# Filepath /content/dataset/train/dog.2255.jpg has dog
# Filepath /content/dataset/train/dog.7152.jpg has dog
# Filepath /content/dataset/train/cat.68.jpg has cat
# Filepath /content/dataset/train/dog.12369.jpg has dog
# Filepath /content/dataset/train/cat.2278.jpg has cat
# Filepath /content/dataset/train/cat.3208.jpg has cat
# Filepath /content/dataset/train/cat.4203.jpg has cat
# Filepath /content/dataset/train/dog.4505.jpg has dog
# Filepath /content/dataset/train/cat.5805.jpg has cat
# Filepath /content/dataset/train/cat.4295.jpg has cat
# Filepath /content/dataset/train/cat.11261.jpg has cat
# Filepath /content/dataset/train/cat.452.jpg has cat
# Filepath /content/dataset/train/cat.8883.jpg has cat
# Filepath /content/dataset/train/cat.5084.jpg has cat
# Filepath /content/dataset/train/dog.2227.jpg has dog
# Filepath /content/dataset/train/dog.5200.jpg has dog
# Filepath /content/dataset/train/cat.1377.jpg has cat
# Filepath /content/dataset/train/cat.11220.jpg has cat
# Filepath /content/dataset/train/cat.10506.jpg has cat
# Filepath /content/dataset/train/cat.5276.jpg has cat
# Filepath /content/dataset/train/cat.10084.jpg has cat
# Filepath /content/dataset/train/dog.7815.jpg has dog
# Filepath /content/dataset/train/dog.11158.jpg has dog
# Filepath /content/dataset/train/cat.4800.jpg has cat
# Filepath /content/dataset/train/dog.11904.jpg has dog
# Filepath /content/dataset/train/cat.12148.jpg has cat
# Filepath /content/dataset/train/cat.3466.jpg has cat
# Filepath /content/dataset/train/cat.2956.jpg has cat
# Filepath /content/dataset/train/dog.9967.jpg has dog
# Filepath /content/dataset/train/cat.9608.jpg has cat
# Filepath /content/dataset/train/dog.5847.jpg has dog
# Filepath /content/dataset/train/cat.7730.jpg has cat
# Filepath /content/dataset/train/cat.3284.jpg has cat
# Filepath /content/dataset/train/cat.3470.jpg has cat
# Filepath /content/dataset/train/dog.5388.jpg has dog
# Filepath /content/dataset/train/dog.5863.jpg has dog
# Filepath /content/dataset/train/cat.2212.jpg has cat
# Filepath /content/dataset/train/dog.10566.jpg has dog
# Filepath /content/dataset/train/cat.11303.jpg has cat
# Filepath /content/dataset/train/cat.8202.jpg has cat
# Filepath /content/dataset/train/cat.9723.jpg has cat
# Filepath /content/dataset/train/cat.12452.jpg has cat
# Filepath /content/dataset/train/dog.4720.jpg has dog
# Filepath /content/dataset/train/dog.4889.jpg has dog
# Filepath /content/dataset/train/dog.11792.jpg has dog
# Filepath /content/dataset/train/dog.12316.jpg has dog
# Filepath /content/dataset/train/cat.6464.jpg has cat
# Filepath /content/dataset/train/dog.5947.jpg has dog
# Filepath /content/dataset/train/dog.12340.jpg has dog
# Filepath /content/dataset/train/dog.812.jpg has dog
# Filepath /content/dataset/train/cat.11603.jpg has cat
# Filepath /content/dataset/train/cat.9391.jpg has cat
# Filepath /content/dataset/train/dog.1781.jpg has dog
# Filepath /content/dataset/train/cat.10335.jpg has cat
# Filepath /content/dataset/train/cat.11364.jpg has cat
# Filepath /content/dataset/train/dog.8525.jpg has dog
# Filepath /content/dataset/train/cat.6857.jpg has cat
# Filepath /content/dataset/train/dog.11102.jpg has dog
# Filepath /content/dataset/train/dog.8236.jpg has dog
# Filepath /content/dataset/train/dog.7872.jpg has dog
# Filepath /content/dataset/train/cat.5004.jpg has cat
# Filepath /content/dataset/train/dog.11352.jpg has dog
# Filepath /content/dataset/train/dog.10542.jpg has dog
# Filepath /content/dataset/train/dog.3611.jpg has dog
# Filepath /content/dataset/train/dog.12026.jpg has dog
# Filepath /content/dataset/train/dog.68.jpg has dog
# Filepath /content/dataset/train/cat.2848.jpg has cat
# Filepath /content/dataset/train/cat.6224.jpg has cat
# Filepath /content/dataset/train/dog.3036.jpg has dog
# Filepath /content/dataset/train/dog.5327.jpg has dog
# Filepath /content/dataset/train/dog.12009.jpg has dog
# Filepath /content/dataset/train/dog.1501.jpg has dog
# Filepath /content/dataset/train/dog.10058.jpg has dog
# Filepath /content/dataset/train/dog.7996.jpg has dog
# Filepath /content/dataset/train/cat.10618.jpg has cat
# Filepath /content/dataset/train/cat.1774.jpg has cat
# Filepath /content/dataset/train/dog.9233.jpg has dog
# Filepath /content/dataset/train/cat.2385.jpg has cat
# Filepath /content/dataset/train/dog.5518.jpg has dog
# Filepath /content/dataset/train/dog.10330.jpg has dog
# Filepath /content/dataset/train/dog.7218.jpg has dog
# Filepath /content/dataset/train/dog.4741.jpg has dog
# Filepath /content/dataset/train/dog.5049.jpg has dog
# Filepath /content/dataset/train/cat.10204.jpg has cat
# Filepath /content/dataset/train/cat.5026.jpg has cat
# Filepath /content/dataset/train/cat.12027.jpg has cat
# Filepath /content/dataset/train/dog.2353.jpg has dog
# Filepath /content/dataset/train/dog.12096.jpg has dog
# Filepath /content/dataset/train/cat.10400.jpg has cat
# Filepath /content/dataset/train/dog.9776.jpg has dog
# Filepath /content/dataset/train/dog.3073.jpg has dog
# Filepath /content/dataset/train/cat.11689.jpg has cat
# Filepath /content/dataset/train/dog.10309.jpg has dog
# Filepath /content/dataset/train/dog.7138.jpg has dog
# Filepath /content/dataset/train/dog.1106.jpg has dog
# Filepath /content/dataset/train/cat.7167.jpg has cat
# Filepath /content/dataset/train/cat.7835.jpg has cat
# Filepath /content/dataset/train/cat.11046.jpg has cat
# Filepath /content/dataset/train/cat.9926.jpg has cat
# Filepath /content/dataset/train/dog.1582.jpg has dog
# Filepath /content/dataset/train/cat.4902.jpg has cat
# Filepath /content/dataset/train/dog.6957.jpg has dog
# Filepath /content/dataset/train/dog.7482.jpg has dog
# Filepath /content/dataset/train/cat.2718.jpg has cat
# Filepath /content/dataset/train/dog.4515.jpg has dog
# Filepath /content/dataset/train/cat.5575.jpg has cat
# Filepath /content/dataset/train/cat.10930.jpg has cat
# Filepath /content/dataset/train/dog.254.jpg has dog
# Filepath /content/dataset/train/dog.11668.jpg has dog
# Filepath /content/dataset/train/cat.853.jpg has cat
# Filepath /content/dataset/train/dog.110.jpg has dog
# Filepath /content/dataset/train/cat.886.jpg has cat
# Filepath /content/dataset/train/cat.9159.jpg has cat
# Filepath /content/dataset/train/cat.5060.jpg has cat
# Filepath /content/dataset/train/dog.4183.jpg has dog
# Filepath /content/dataset/train/cat.6768.jpg has cat
# Filepath /content/dataset/train/cat.9359.jpg has cat
# Filepath /content/dataset/train/cat.2334.jpg has cat
# Filepath /content/dataset/train/cat.3322.jpg has cat
# Filepath /content/dataset/train/cat.8272.jpg has cat
# Filepath /content/dataset/train/dog.8763.jpg has dog
# Filepath /content/dataset/train/dog.10106.jpg has dog
# Filepath /content/dataset/train/cat.2295.jpg has cat
# Filepath /content/dataset/train/cat.220.jpg has cat
# Filepath /content/dataset/train/cat.2724.jpg has cat
# Filepath /content/dataset/train/cat.2400.jpg has cat
# Filepath /content/dataset/train/dog.7663.jpg has dog
# Filepath /content/dataset/train/cat.12416.jpg has cat
# Filepath /content/dataset/train/cat.4036.jpg has cat
# Filepath /content/dataset/train/dog.1777.jpg has dog
# Filepath /content/dataset/train/dog.12293.jpg has dog
# Filepath /content/dataset/train/cat.7537.jpg has cat
# Filepath /content/dataset/train/dog.5475.jpg has dog
# Filepath /content/dataset/train/dog.6699.jpg has dog
# Filepath /content/dataset/train/cat.3458.jpg has cat
# Filepath /content/dataset/train/cat.9297.jpg has cat
# Filepath /content/dataset/train/cat.6236.jpg has cat
# Filepath /content/dataset/train/dog.9377.jpg has dog
# Filepath /content/dataset/train/cat.7849.jpg has cat
# Filepath /content/dataset/train/dog.1842.jpg has dog
# Filepath /content/dataset/train/cat.3283.jpg has cat
# Filepath /content/dataset/train/dog.12481.jpg has dog
# Filepath /content/dataset/train/cat.880.jpg has cat
# Filepath /content/dataset/train/dog.7055.jpg has dog
# Filepath /content/dataset/train/dog.3209.jpg has dog
# Filepath /content/dataset/train/dog.1214.jpg has dog
# Filepath /content/dataset/train/dog.6039.jpg has dog
# Filepath /content/dataset/train/cat.6468.jpg has cat
# Filepath /content/dataset/train/cat.6964.jpg has cat
# Filepath /content/dataset/train/dog.7808.jpg has dog
# Filepath /content/dataset/train/cat.2130.jpg has cat
# Filepath /content/dataset/train/cat.7052.jpg has cat
# Filepath /content/dataset/train/cat.11670.jpg has cat
# Filepath /content/dataset/train/dog.9111.jpg has dog
# Filepath /content/dataset/train/dog.795.jpg has dog
# Filepath /content/dataset/train/dog.3143.jpg has dog
# Filepath /content/dataset/train/dog.2528.jpg has dog
# Filepath /content/dataset/train/dog.7034.jpg has dog
# Filepath /content/dataset/train/dog.3367.jpg has dog
# Filepath /content/dataset/train/cat.3810.jpg has cat
# Filepath /content/dataset/train/dog.5503.jpg has dog
# Filepath /content/dataset/train/dog.2617.jpg has dog
# Filepath /content/dataset/train/cat.9587.jpg has cat
# Filepath /content/dataset/train/cat.2906.jpg has cat
# Filepath /content/dataset/train/cat.2613.jpg has cat
# Filepath /content/dataset/train/dog.11586.jpg has dog
# Filepath /content/dataset/train/dog.2347.jpg has dog
# Filepath /content/dataset/train/cat.2431.jpg has cat
# Filepath /content/dataset/train/cat.4396.jpg has cat
# Filepath /content/dataset/train/cat.1977.jpg has cat
# Filepath /content/dataset/train/cat.10698.jpg has cat
# Filepath /content/dataset/train/dog.4160.jpg has dog
# Filepath /content/dataset/train/dog.9134.jpg has dog
# Filepath /content/dataset/train/dog.6408.jpg has dog
# Filepath /content/dataset/train/dog.8498.jpg has dog
# Filepath /content/dataset/train/cat.6411.jpg has cat
# Filepath /content/dataset/train/dog.6351.jpg has dog
# Filepath /content/dataset/train/cat.1268.jpg has cat
# Filepath /content/dataset/train/dog.7917.jpg has dog
# Filepath /content/dataset/train/cat.2289.jpg has cat
# Filepath /content/dataset/train/dog.5411.jpg has dog
# Filepath /content/dataset/train/cat.8876.jpg has cat
# Filepath /content/dataset/train/cat.12029.jpg has cat
# Filepath /content/dataset/train/dog.8576.jpg has dog
# Filepath /content/dataset/train/dog.790.jpg has dog
# Filepath /content/dataset/train/cat.4376.jpg has cat
# Filepath /content/dataset/train/cat.2132.jpg has cat
# Filepath /content/dataset/train/cat.11154.jpg has cat
# Filepath /content/dataset/train/dog.3025.jpg has dog
# Filepath /content/dataset/train/dog.3865.jpg has dog
# Filepath /content/dataset/train/cat.7599.jpg has cat
# Filepath /content/dataset/train/dog.4696.jpg has dog
# Filepath /content/dataset/train/dog.10035.jpg has dog
# Filepath /content/dataset/train/dog.874.jpg has dog
# Filepath /content/dataset/train/dog.11160.jpg has dog
# Filepath /content/dataset/train/dog.9868.jpg has dog
# Filepath /content/dataset/train/cat.8959.jpg has cat
# Filepath /content/dataset/train/cat.117.jpg has cat
# Filepath /content/dataset/train/cat.2680.jpg has cat
# Filepath /content/dataset/train/dog.12312.jpg has dog
# Filepath /content/dataset/train/dog.4619.jpg has dog
# Filepath /content/dataset/train/dog.12305.jpg has dog
# Filepath /content/dataset/train/cat.9310.jpg has cat
# Filepath /content/dataset/train/cat.10859.jpg has cat
# Filepath /content/dataset/train/cat.3582.jpg has cat
# Filepath /content/dataset/train/dog.2868.jpg has dog
# Filepath /content/dataset/train/dog.10991.jpg has dog
# Filepath /content/dataset/train/cat.7841.jpg has cat
# Filepath /content/dataset/train/cat.11317.jpg has cat
# Filepath /content/dataset/train/dog.11940.jpg has dog
# Filepath /content/dataset/train/dog.4221.jpg has dog
# Filepath /content/dataset/train/cat.1868.jpg has cat
# Filepath /content/dataset/train/cat.4301.jpg has cat
# Filepath /content/dataset/train/cat.6957.jpg has cat
# Filepath /content/dataset/train/cat.6967.jpg has cat
# Filepath /content/dataset/train/dog.11392.jpg has dog
# Filepath /content/dataset/train/dog.5321.jpg has dog
# Filepath /content/dataset/train/cat.6652.jpg has cat
# Filepath /content/dataset/train/dog.11746.jpg has dog
# Filepath /content/dataset/train/dog.10467.jpg has dog
# Filepath /content/dataset/train/dog.6246.jpg has dog
# Filepath /content/dataset/train/cat.11371.jpg has cat
# Filepath /content/dataset/train/cat.4319.jpg has cat
# Filepath /content/dataset/train/dog.4363.jpg has dog
# Filepath /content/dataset/train/dog.11726.jpg has dog
# Filepath /content/dataset/train/cat.1339.jpg has cat
# Filepath /content/dataset/train/cat.4193.jpg has cat
# Filepath /content/dataset/train/cat.11013.jpg has cat
# Filepath /content/dataset/train/dog.6452.jpg has dog
# Filepath /content/dataset/train/cat.11036.jpg has cat
# Filepath /content/dataset/train/cat.7283.jpg has cat
# Filepath /content/dataset/train/cat.4255.jpg has cat
# Filepath /content/dataset/train/dog.8711.jpg has dog
# Filepath /content/dataset/train/cat.7258.jpg has cat
# Filepath /content/dataset/train/dog.10700.jpg has dog
# Filepath /content/dataset/train/cat.8361.jpg has cat
# Filepath /content/dataset/train/dog.2797.jpg has dog
# Filepath /content/dataset/train/dog.5376.jpg has dog
# Filepath /content/dataset/train/cat.9059.jpg has cat
# Filepath /content/dataset/train/dog.9695.jpg has dog
# Filepath /content/dataset/train/cat.6297.jpg has cat
# Filepath /content/dataset/train/dog.69.jpg has dog
# Filepath /content/dataset/train/dog.10478.jpg has dog
# Filepath /content/dataset/train/dog.6919.jpg has dog
# Filepath /content/dataset/train/dog.7111.jpg has dog
# Filepath /content/dataset/train/cat.10419.jpg has cat
# Filepath /content/dataset/train/dog.859.jpg has dog
# Filepath /content/dataset/train/cat.10691.jpg has cat
# Filepath /content/dataset/train/dog.11031.jpg has dog
# Filepath /content/dataset/train/dog.4595.jpg has dog
# Filepath /content/dataset/train/cat.3666.jpg has cat
# Filepath /content/dataset/train/cat.11723.jpg has cat
# Filepath /content/dataset/train/cat.3798.jpg has cat
# Filepath /content/dataset/train/cat.6890.jpg has cat
# Filepath /content/dataset/train/dog.11438.jpg has dog
# Filepath /content/dataset/train/cat.8961.jpg has cat
# Filepath /content/dataset/train/dog.7464.jpg has dog
# Filepath /content/dataset/train/dog.4004.jpg has dog
# Filepath /content/dataset/train/cat.11659.jpg has cat
# Filepath /content/dataset/train/cat.10489.jpg has cat
# Filepath /content/dataset/train/cat.8990.jpg has cat
# Filepath /content/dataset/train/dog.3700.jpg has dog
# Filepath /content/dataset/train/dog.11250.jpg has dog
# Filepath /content/dataset/train/dog.10595.jpg has dog
# Filepath /content/dataset/train/dog.8981.jpg has dog
# Filepath /content/dataset/train/dog.4826.jpg has dog
# Filepath /content/dataset/train/dog.992.jpg has dog
# Filepath /content/dataset/train/cat.1870.jpg has cat
# Filepath /content/dataset/train/dog.1372.jpg has dog
# Filepath /content/dataset/train/cat.4304.jpg has cat
# Filepath /content/dataset/train/cat.6892.jpg has cat
# Filepath /content/dataset/train/cat.9342.jpg has cat
# Filepath /content/dataset/train/cat.12333.jpg has cat
# Filepath /content/dataset/train/cat.9038.jpg has cat
# Filepath /content/dataset/train/cat.5045.jpg has cat
# Filepath /content/dataset/train/dog.3766.jpg has dog
# Filepath /content/dataset/train/cat.3809.jpg has cat
# Filepath /content/dataset/train/cat.3453.jpg has cat
# Filepath /content/dataset/train/cat.2244.jpg has cat
# Filepath /content/dataset/train/dog.253.jpg has dog
# Filepath /content/dataset/train/dog.33.jpg has dog
# Filepath /content/dataset/train/cat.989.jpg has cat
# Filepath /content/dataset/train/dog.1481.jpg has dog
# Filepath /content/dataset/train/cat.9566.jpg has cat
# Filepath /content/dataset/train/dog.1521.jpg has dog
# Filepath /content/dataset/train/dog.9848.jpg has dog
# Filepath /content/dataset/train/cat.11151.jpg has cat
# Filepath /content/dataset/train/dog.2504.jpg has dog
# Filepath /content/dataset/train/dog.11868.jpg has dog
# Filepath /content/dataset/train/dog.8563.jpg has dog
# Filepath /content/dataset/train/dog.5332.jpg has dog
# Filepath /content/dataset/train/cat.8225.jpg has cat
# Filepath /content/dataset/train/dog.12018.jpg has dog
# Filepath /content/dataset/train/dog.1615.jpg has dog
# Filepath /content/dataset/train/dog.11309.jpg has dog
# Filepath /content/dataset/train/cat.3678.jpg has cat
# Filepath /content/dataset/train/cat.2723.jpg has cat
# Filepath /content/dataset/train/cat.5757.jpg has cat
# Filepath /content/dataset/train/dog.4845.jpg has dog
# Filepath /content/dataset/train/dog.2553.jpg has dog
# Filepath /content/dataset/train/cat.9762.jpg has cat
# Filepath /content/dataset/train/dog.3741.jpg has dog
# Filepath /content/dataset/train/cat.5337.jpg has cat
# Filepath /content/dataset/train/cat.11889.jpg has cat
# Filepath /content/dataset/train/dog.599.jpg has dog
# Filepath /content/dataset/train/cat.5078.jpg has cat
# Filepath /content/dataset/train/cat.12431.jpg has cat
# Filepath /content/dataset/train/dog.4497.jpg has dog
# Filepath /content/dataset/train/cat.1836.jpg has cat
# Filepath /content/dataset/train/cat.5599.jpg has cat
# Filepath /content/dataset/train/cat.144.jpg has cat
# Filepath /content/dataset/train/dog.10699.jpg has dog
# Filepath /content/dataset/train/dog.4767.jpg has dog
# Filepath /content/dataset/train/cat.8141.jpg has cat
# Filepath /content/dataset/train/cat.6685.jpg has cat
# Filepath /content/dataset/train/dog.8339.jpg has dog
# Filepath /content/dataset/train/cat.9790.jpg has cat
# Filepath /content/dataset/train/dog.44.jpg has dog
# Filepath /content/dataset/train/dog.5512.jpg has dog
# Filepath /content/dataset/train/cat.5515.jpg has cat
# Filepath /content/dataset/train/cat.11460.jpg has cat
# Filepath /content/dataset/train/dog.7679.jpg has dog
# Filepath /content/dataset/train/cat.7146.jpg has cat
# Filepath /content/dataset/train/cat.6449.jpg has cat
# Filepath /content/dataset/train/dog.3216.jpg has dog
# Filepath /content/dataset/train/cat.113.jpg has cat
# Filepath /content/dataset/train/dog.10352.jpg has dog
# Filepath /content/dataset/train/dog.11057.jpg has dog
# Filepath /content/dataset/train/cat.5020.jpg has cat
# Filepath /content/dataset/train/cat.4436.jpg has cat
# Filepath /content/dataset/train/dog.5350.jpg has dog
# Filepath /content/dataset/train/cat.1375.jpg has cat
# Filepath /content/dataset/train/cat.8622.jpg has cat
# Filepath /content/dataset/train/dog.11831.jpg has dog
# Filepath /content/dataset/train/dog.7906.jpg has dog
# Filepath /content/dataset/train/dog.2138.jpg has dog
# Filepath /content/dataset/train/dog.7341.jpg has dog
# Filepath /content/dataset/train/dog.10080.jpg has dog
# Filepath /content/dataset/train/cat.9390.jpg has cat
# Filepath /content/dataset/train/dog.7932.jpg has dog
# Filepath /content/dataset/train/cat.5202.jpg has cat
# Filepath /content/dataset/train/dog.10761.jpg has dog
# Filepath /content/dataset/train/dog.11897.jpg has dog
# Filepath /content/dataset/train/dog.5256.jpg has dog
# Filepath /content/dataset/train/dog.7930.jpg has dog
# Filepath /content/dataset/train/dog.4603.jpg has dog
# Filepath /content/dataset/train/dog.1177.jpg has dog
# Filepath /content/dataset/train/cat.7412.jpg has cat
# Filepath /content/dataset/train/dog.3444.jpg has dog
# Filepath /content/dataset/train/dog.11733.jpg has dog
# Filepath /content/dataset/train/dog.5849.jpg has dog
# Filepath /content/dataset/train/cat.1969.jpg has cat
# Filepath /content/dataset/train/cat.1309.jpg has cat
# Filepath /content/dataset/train/dog.11643.jpg has dog
# Filepath /content/dataset/train/dog.10548.jpg has dog
# Filepath /content/dataset/train/cat.4131.jpg has cat
# Filepath /content/dataset/train/cat.8416.jpg has cat
# Filepath /content/dataset/train/cat.2612.jpg has cat
# Filepath /content/dataset/train/cat.8505.jpg has cat
# Filepath /content/dataset/train/dog.8345.jpg has dog
# Filepath /content/dataset/train/cat.970.jpg has cat
# Filepath /content/dataset/train/dog.8292.jpg has dog
# Filepath /content/dataset/train/dog.11681.jpg has dog
# Filepath /content/dataset/train/dog.11931.jpg has dog
# Filepath /content/dataset/train/dog.6000.jpg has dog
# Filepath /content/dataset/train/dog.8077.jpg has dog
# Filepath /content/dataset/train/cat.2849.jpg has cat
# Filepath /content/dataset/train/dog.489.jpg has dog
# Filepath /content/dataset/train/dog.4218.jpg has dog
# Filepath /content/dataset/train/cat.7142.jpg has cat
# Filepath /content/dataset/train/dog.1758.jpg has dog
# Filepath /content/dataset/train/dog.6682.jpg has dog
# Filepath /content/dataset/train/cat.4448.jpg has cat
# Filepath /content/dataset/train/dog.8812.jpg has dog
# Filepath /content/dataset/train/dog.8314.jpg has dog
# Filepath /content/dataset/train/cat.7948.jpg has cat
# Filepath /content/dataset/train/dog.7713.jpg has dog
# Filepath /content/dataset/train/cat.4903.jpg has cat
# Filepath /content/dataset/train/cat.6482.jpg has cat
# Filepath /content/dataset/train/cat.6887.jpg has cat
# Filepath /content/dataset/train/dog.7807.jpg has dog
# Filepath /content/dataset/train/cat.2116.jpg has cat
# Filepath /content/dataset/train/dog.6958.jpg has dog
# Filepath /content/dataset/train/dog.11660.jpg has dog
# Filepath /content/dataset/train/dog.2597.jpg has dog
# Filepath /content/dataset/train/dog.11848.jpg has dog
# Filepath /content/dataset/train/cat.5439.jpg has cat
# Filepath /content/dataset/train/dog.5640.jpg has dog
# Filepath /content/dataset/train/dog.7395.jpg has dog
# Filepath /content/dataset/train/dog.11676.jpg has dog
# Filepath /content/dataset/train/dog.665.jpg has dog
# Filepath /content/dataset/train/cat.1257.jpg has cat
# Filepath /content/dataset/train/dog.5641.jpg has dog
# Filepath /content/dataset/train/cat.7855.jpg has cat
# Filepath /content/dataset/train/cat.1243.jpg has cat
# Filepath /content/dataset/train/dog.5090.jpg has dog
# Filepath /content/dataset/train/cat.8374.jpg has cat
# Filepath /content/dataset/train/dog.5126.jpg has dog
# Filepath /content/dataset/train/dog.5194.jpg has dog
# Filepath /content/dataset/train/cat.4426.jpg has cat
# Filepath /content/dataset/train/cat.5474.jpg has cat
# Filepath /content/dataset/train/cat.9472.jpg has cat
# Filepath /content/dataset/train/cat.6136.jpg has cat
# Filepath /content/dataset/train/dog.2921.jpg has dog
# Filepath /content/dataset/train/dog.2860.jpg has dog
# Filepath /content/dataset/train/cat.1617.jpg has cat
# Filepath /content/dataset/train/cat.8101.jpg has cat
# Filepath /content/dataset/train/dog.11948.jpg has dog
# Filepath /content/dataset/train/cat.8379.jpg has cat
# Filepath /content/dataset/train/cat.2338.jpg has cat
# Filepath /content/dataset/train/cat.4229.jpg has cat
# Filepath /content/dataset/train/cat.3435.jpg has cat
# Filepath /content/dataset/train/dog.4389.jpg has dog
# Filepath /content/dataset/train/cat.44.jpg has cat
# Filepath /content/dataset/train/cat.5918.jpg has cat
# Filepath /content/dataset/train/cat.3438.jpg has cat
# Filepath /content/dataset/train/cat.2014.jpg has cat
# Filepath /content/dataset/train/dog.9954.jpg has dog
# Filepath /content/dataset/train/dog.5473.jpg has dog
# Filepath /content/dataset/train/cat.8551.jpg has cat
# Filepath /content/dataset/train/cat.9095.jpg has cat
# Filepath /content/dataset/train/dog.786.jpg has dog
# Filepath /content/dataset/train/dog.4030.jpg has dog
# Filepath /content/dataset/train/dog.4836.jpg has dog
# Filepath /content/dataset/train/dog.8231.jpg has dog
# Filepath /content/dataset/train/dog.8143.jpg has dog
# Filepath /content/dataset/train/dog.1968.jpg has dog
# Filepath /content/dataset/train/dog.3488.jpg has dog
# Filepath /content/dataset/train/dog.4050.jpg has dog
# Filepath /content/dataset/train/dog.11959.jpg has dog
# Filepath /content/dataset/train/dog.824.jpg has dog
# Filepath /content/dataset/train/cat.8367.jpg has cat
# Filepath /content/dataset/train/cat.8254.jpg has cat
# Filepath /content/dataset/train/cat.1096.jpg has cat
# Filepath /content/dataset/train/dog.1609.jpg has dog
# Filepath /content/dataset/train/cat.4712.jpg has cat
# Filepath /content/dataset/train/cat.4467.jpg has cat
# Filepath /content/dataset/train/dog.4448.jpg has dog
# Filepath /content/dataset/train/dog.6426.jpg has dog
# Filepath /content/dataset/train/dog.5853.jpg has dog
# Filepath /content/dataset/train/cat.12210.jpg has cat
# Filepath /content/dataset/train/cat.11175.jpg has cat
# Filepath /content/dataset/train/cat.7665.jpg has cat
# Filepath /content/dataset/train/dog.3798.jpg has dog
# Filepath /content/dataset/train/cat.9002.jpg has cat
# Filepath /content/dataset/train/cat.195.jpg has cat
# Filepath /content/dataset/train/cat.8105.jpg has cat
# Filepath /content/dataset/train/dog.10337.jpg has dog
# Filepath /content/dataset/train/dog.5811.jpg has dog
# Filepath /content/dataset/train/cat.4013.jpg has cat
# Filepath /content/dataset/train/dog.6161.jpg has dog
# Filepath /content/dataset/train/dog.3205.jpg has dog
# Filepath /content/dataset/train/cat.4502.jpg has cat
# Filepath /content/dataset/train/dog.8756.jpg has dog
# Filepath /content/dataset/train/dog.1182.jpg has dog
# Filepath /content/dataset/train/cat.7928.jpg has cat
# Filepath /content/dataset/train/cat.1705.jpg has cat
# Filepath /content/dataset/train/cat.10313.jpg has cat
# Filepath /content/dataset/train/cat.8623.jpg has cat
# Filepath /content/dataset/train/dog.5111.jpg has dog
# Filepath /content/dataset/train/cat.5729.jpg has cat
# Filepath /content/dataset/train/cat.594.jpg has cat
# Filepath /content/dataset/train/dog.3013.jpg has dog
# Filepath /content/dataset/train/dog.11927.jpg has dog
# Filepath /content/dataset/train/cat.4961.jpg has cat
# Filepath /content/dataset/train/cat.960.jpg has cat
# Filepath /content/dataset/train/cat.415.jpg has cat
# Filepath /content/dataset/train/cat.8001.jpg has cat
# Filepath /content/dataset/train/dog.1765.jpg has dog
# Filepath /content/dataset/train/cat.9299.jpg has cat
# Filepath /content/dataset/train/cat.6770.jpg has cat
# Filepath /content/dataset/train/dog.2748.jpg has dog
# Filepath /content/dataset/train/dog.1737.jpg has dog
# Filepath /content/dataset/train/cat.3050.jpg has cat
# Filepath /content/dataset/train/dog.486.jpg has dog
# Filepath /content/dataset/train/dog.9044.jpg has dog
# Filepath /content/dataset/train/cat.2294.jpg has cat
# Filepath /content/dataset/train/cat.7873.jpg has cat
# Filepath /content/dataset/train/dog.9367.jpg has dog
# Filepath /content/dataset/train/dog.4031.jpg has dog
# Filepath /content/dataset/train/dog.10957.jpg has dog
# Filepath /content/dataset/train/cat.3104.jpg has cat
# Filepath /content/dataset/train/dog.2457.jpg has dog
# Filepath /content/dataset/train/cat.7742.jpg has cat
# Filepath /content/dataset/train/cat.8713.jpg has cat
# Filepath /content/dataset/train/cat.5143.jpg has cat
# Filepath /content/dataset/train/cat.2192.jpg has cat
# Filepath /content/dataset/train/dog.1435.jpg has dog
# Filepath /content/dataset/train/dog.756.jpg has dog
# Filepath /content/dataset/train/cat.11256.jpg has cat
# Filepath /content/dataset/train/dog.381.jpg has dog
# Filepath /content/dataset/train/cat.11971.jpg has cat
# Filepath /content/dataset/train/dog.6904.jpg has dog
# Filepath /content/dataset/train/dog.2215.jpg has dog
# Filepath /content/dataset/train/dog.3427.jpg has dog
# Filepath /content/dataset/train/cat.2824.jpg has cat
# Filepath /content/dataset/train/dog.4623.jpg has dog
# Filepath /content/dataset/train/dog.11543.jpg has dog
# Filepath /content/dataset/train/cat.5786.jpg has cat
# Filepath /content/dataset/train/dog.11515.jpg has dog
# Filepath /content/dataset/train/cat.440.jpg has cat
# Filepath /content/dataset/train/dog.9128.jpg has dog
# Filepath /content/dataset/train/dog.10119.jpg has dog
# Filepath /content/dataset/train/dog.6253.jpg has dog
# Filepath /content/dataset/train/cat.7408.jpg has cat
# Filepath /content/dataset/train/dog.2875.jpg has dog
# Filepath /content/dataset/train/dog.9239.jpg has dog
# Filepath /content/dataset/train/dog.380.jpg has dog
# Filepath /content/dataset/train/dog.10754.jpg has dog
# Filepath /content/dataset/train/dog.3220.jpg has dog
# Filepath /content/dataset/train/cat.1918.jpg has cat
# Filepath /content/dataset/train/dog.11956.jpg has dog
# Filepath /content/dataset/train/cat.7473.jpg has cat
# Filepath /content/dataset/train/dog.11685.jpg has dog
# Filepath /content/dataset/train/cat.9526.jpg has cat
# Filepath /content/dataset/train/dog.3502.jpg has dog
# Filepath /content/dataset/train/cat.4034.jpg has cat
# Filepath /content/dataset/train/cat.4118.jpg has cat
# Filepath /content/dataset/train/dog.3969.jpg has dog
# Filepath /content/dataset/train/cat.6202.jpg has cat
# Filepath /content/dataset/train/cat.4492.jpg has cat
# Filepath /content/dataset/train/cat.2901.jpg has cat
# Filepath /content/dataset/train/dog.11156.jpg has dog
# Filepath /content/dataset/train/dog.10155.jpg has dog
# Filepath /content/dataset/train/dog.1629.jpg has dog
# Filepath /content/dataset/train/dog.10996.jpg has dog
# Filepath /content/dataset/train/cat.214.jpg has cat
# Filepath /content/dataset/train/dog.11314.jpg has dog
# Filepath /content/dataset/train/dog.319.jpg has dog
# Filepath /content/dataset/train/cat.840.jpg has cat
# Filepath /content/dataset/train/cat.524.jpg has cat
# Filepath /content/dataset/train/dog.2614.jpg has dog
# Filepath /content/dataset/train/dog.6828.jpg has dog
# Filepath /content/dataset/train/cat.2701.jpg has cat
# Filepath /content/dataset/train/cat.10734.jpg has cat
# Filepath /content/dataset/train/cat.7877.jpg has cat
# Filepath /content/dataset/train/dog.5371.jpg has dog
# Filepath /content/dataset/train/cat.5018.jpg has cat
# Filepath /content/dataset/train/dog.1889.jpg has dog
# Filepath /content/dataset/train/dog.4746.jpg has dog
# Filepath /content/dataset/train/cat.6286.jpg has cat
# Filepath /content/dataset/train/dog.5713.jpg has dog
# Filepath /content/dataset/train/cat.7657.jpg has cat
# ...
# Filepath /content/dataset/train/dog.2972.jpg has dog
# Filepath /content/dataset/train/dog.6987.jpg has dog
# Filepath /content/dataset/train/cat.7910.jpg has cat
# Filepath /content/dataset/train/cat.8043.jpg has cat
# Filepath /content/dataset/train/cat.3700.jpg has cat
# Filepath /content/dataset/train/cat.668.jpg has cat
# Filepath /content/dataset/train/cat.9681.jpg has cat
# Filepath /content/dataset/train/dog.11995.jpg has dog
# Filepath /content/dataset/train/cat.3387.jpg has cat
# Filepath /content/dataset/train/dog.959.jpg has dog
# Filepath /content/dataset/train/dog.6857.jpg has dog
# Filepath /content/dataset/train/dog.10517.jpg has dog
# Filepath /content/dataset/train/dog.11967.jpg has dog
# Filepath /content/dataset/train/cat.12296.jpg has cat
# Filepath /content/dataset/train/dog.4763.jpg has dog
# Filepath /content/dataset/train/cat.7268.jpg has cat
# Filepath /content/dataset/train/dog.12343.jpg has dog
# Filepath /content/dataset/train/dog.4281.jpg has dog
# Filepath /content/dataset/train/dog.7633.jpg has dog
# Filepath /content/dataset/train/cat.3354.jpg has cat
# Filepath /content/dataset/train/cat.1849.jpg has cat
# Filepath /content/dataset/train/cat.2209.jpg has cat
# Filepath /content/dataset/train/cat.2831.jpg has cat
# Filepath /content/dataset/train/dog.2249.jpg has dog
# Filepath /content/dataset/train/dog.5772.jpg has dog
# Filepath /content/dataset/train/cat.5275.jpg has cat
# Filepath /content/dataset/train/cat.6378.jpg has cat
# Filepath /content/dataset/train/dog.7635.jpg has dog
# Filepath /content/dataset/train/dog.4088.jpg has dog
# Filepath /content/dataset/train/cat.5673.jpg has cat
# Filepath /content/dataset/train/dog.698.jpg has dog
# Filepath /content/dataset/train/dog.12195.jpg has dog
# Filepath /content/dataset/train/cat.2199.jpg has cat
# Filepath /content/dataset/train/cat.6501.jpg has cat
# Filepath /content/dataset/train/cat.6999.jpg has cat
# Filepath /content/dataset/train/dog.4.jpg has dog
# Filepath /content/dataset/train/dog.11843.jpg has dog
# Filepath /content/dataset/train/cat.2904.jpg has cat
# Filepath /content/dataset/train/dog.123.jpg has dog
# Filepath /content/dataset/train/dog.8861.jpg has dog
# Filepath /content/dataset/train/cat.12054.jpg has cat
# Filepath /content/dataset/train/dog.2883.jpg has dog
# Filepath /content/dataset/train/cat.350.jpg has cat
# Filepath /content/dataset/train/dog.9510.jpg has dog
# Filepath /content/dataset/train/dog.12274.jpg has dog
# Filepath /content/dataset/train/dog.7406.jpg has dog
# Filepath /content/dataset/train/cat.6390.jpg has cat
# Filepath /content/dataset/train/cat.9091.jpg has cat
# Filepath /content/dataset/train/dog.10917.jpg has dog
# Filepath /content/dataset/train/dog.3047.jpg has dog
# Filepath /content/dataset/train/dog.5338.jpg has dog
# Filepath /content/dataset/train/cat.12479.jpg has cat
# Filepath /content/dataset/train/cat.3815.jpg has cat
# Filepath /content/dataset/train/dog.692.jpg has dog
# Filepath /content/dataset/train/cat.1409.jpg has cat
# Filepath /content/dataset/train/dog.10551.jpg has dog
# Filepath /content/dataset/train/dog.10807.jpg has dog
# Filepath /content/dataset/train/dog.5320.jpg has dog
# Filepath /content/dataset/train/dog.5918.jpg has dog
# Filepath /content/dataset/train/cat.7350.jpg has cat
# Filepath /content/dataset/train/dog.5412.jpg has dog
# Filepath /content/dataset/train/dog.780.jpg has dog
# Filepath /content/dataset/train/dog.4537.jpg has dog
# Filepath /content/dataset/train/dog.5672.jpg has dog
# Filepath /content/dataset/train/dog.4738.jpg has dog
# Filepath /content/dataset/train/dog.1122.jpg has dog
# Filepath /content/dataset/train/dog.1511.jpg has dog
# Filepath /content/dataset/train/dog.5895.jpg has dog
# Filepath /content/dataset/train/cat.5073.jpg has cat
# Filepath /content/dataset/train/cat.11778.jpg has cat
# Filepath /content/dataset/train/dog.1382.jpg has dog
# Filepath /content/dataset/train/cat.1440.jpg has cat
# Filepath /content/dataset/train/cat.2207.jpg has cat
# Filepath /content/dataset/train/cat.5923.jpg has cat
# Filepath /content/dataset/train/cat.5410.jpg has cat
# Filepath /content/dataset/train/cat.12239.jpg has cat
# Filepath /content/dataset/train/cat.10282.jpg has cat
# Filepath /content/dataset/train/dog.9099.jpg has dog
# Filepath /content/dataset/train/cat.1793.jpg has cat
# Filepath /content/dataset/train/cat.2541.jpg has cat
# Filepath /content/dataset/train/cat.7882.jpg has cat
# Filepath /content/dataset/train/cat.250.jpg has cat
# Filepath /content/dataset/train/dog.225.jpg has dog
# Filepath /content/dataset/train/dog.8494.jpg has dog
# Filepath /content/dataset/train/cat.6738.jpg has cat
# Filepath /content/dataset/train/dog.737.jpg has dog
# Filepath /content/dataset/train/cat.7084.jpg has cat
# Filepath /content/dataset/train/dog.9489.jpg has dog
# Filepath /content/dataset/train/dog.10046.jpg has dog
# Filepath /content/dataset/train/cat.9293.jpg has cat
# Filepath /content/dataset/train/dog.8851.jpg has dog
# Filepath /content/dataset/train/dog.2349.jpg has dog
# Filepath /content/dataset/train/cat.6146.jpg has cat
# Filepath /content/dataset/train/dog.5682.jpg has dog
# Filepath /content/dataset/train/dog.5645.jpg has dog
# Filepath /content/dataset/train/cat.9550.jpg has cat
# Filepath /content/dataset/train/dog.9386.jpg has dog
# Filepath /content/dataset/train/dog.6521.jpg has dog
# Filepath /content/dataset/train/dog.114.jpg has dog
# Filepath /content/dataset/train/cat.5870.jpg has cat
# Filepath /content/dataset/train/dog.2812.jpg has dog
# Filepath /content/dataset/train/dog.1964.jpg has dog
# Filepath /content/dataset/train/dog.3988.jpg has dog
# Filepath /content/dataset/train/cat.2356.jpg has cat
# Filepath /content/dataset/train/cat.9006.jpg has cat
# Filepath /content/dataset/train/dog.12388.jpg has dog
# Filepath /content/dataset/train/dog.9275.jpg has dog
# Filepath /content/dataset/train/cat.7220.jpg has cat
# Filepath /content/dataset/train/cat.1024.jpg has cat
# Filepath /content/dataset/train/cat.12496.jpg has cat
# Filepath /content/dataset/train/dog.1023.jpg has dog
# Filepath /content/dataset/train/dog.2735.jpg has dog
# Filepath /content/dataset/train/dog.10040.jpg has dog
# Filepath /content/dataset/train/cat.11293.jpg has cat
# Filepath /content/dataset/train/dog.3630.jpg has dog
# Filepath /content/dataset/train/dog.5337.jpg has dog
# Filepath /content/dataset/train/cat.6027.jpg has cat
# Filepath /content/dataset/train/cat.8796.jpg has cat
# Filepath /content/dataset/train/cat.5634.jpg has cat
# Filepath /content/dataset/train/cat.9622.jpg has cat
# Filepath /content/dataset/train/dog.6557.jpg has dog
# Filepath /content/dataset/train/dog.5500.jpg has dog
# Filepath /content/dataset/train/cat.2644.jpg has cat
# Filepath /content/dataset/train/cat.4310.jpg has cat
# Filepath /content/dataset/train/dog.9501.jpg has dog
# Filepath /content/dataset/train/cat.1661.jpg has cat
# Filepath /content/dataset/train/cat.2064.jpg has cat
# Filepath /content/dataset/train/dog.6839.jpg has dog
# Filepath /content/dataset/train/cat.6004.jpg has cat
# Filepath /content/dataset/train/cat.2175.jpg has cat
# Filepath /content/dataset/train/dog.8920.jpg has dog
# Filepath /content/dataset/train/dog.9368.jpg has dog
# Filepath /content/dataset/train/dog.797.jpg has dog
# Filepath /content/dataset/train/cat.6466.jpg has cat
# Filepath /content/dataset/train/dog.4719.jpg has dog
# Filepath /content/dataset/train/dog.2090.jpg has dog
# Filepath /content/dataset/train/dog.3809.jpg has dog
# Filepath /content/dataset/train/dog.1799.jpg has dog
# Filepath /content/dataset/train/cat.796.jpg has cat
# Filepath /content/dataset/train/dog.4067.jpg has dog
# Filepath /content/dataset/train/cat.11287.jpg has cat
# Filepath /content/dataset/train/cat.8988.jpg has cat
# Filepath /content/dataset/train/cat.9257.jpg has cat
# Filepath /content/dataset/train/dog.520.jpg has dog
# Filepath /content/dataset/train/cat.3402.jpg has cat
# Filepath /content/dataset/train/cat.7355.jpg has cat
# Filepath /content/dataset/train/cat.6354.jpg has cat
# Filepath /content/dataset/train/dog.8206.jpg has dog
# Filepath /content/dataset/train/cat.6903.jpg has cat
# Filepath /content/dataset/train/cat.8538.jpg has cat
# Filepath /content/dataset/train/dog.10816.jpg has dog
# Filepath /content/dataset/train/cat.2705.jpg has cat
# Filepath /content/dataset/train/dog.9759.jpg has dog
# Filepath /content/dataset/train/cat.4550.jpg has cat
# Filepath /content/dataset/train/cat.8156.jpg has cat
# Filepath /content/dataset/train/dog.4501.jpg has dog
# Filepath /content/dataset/train/dog.11735.jpg has dog
# Filepath /content/dataset/train/dog.331.jpg has dog
# Filepath /content/dataset/train/dog.7755.jpg has dog
# Filepath /content/dataset/train/dog.6806.jpg has dog
# Filepath /content/dataset/train/dog.1384.jpg has dog
# Filepath /content/dataset/train/cat.6808.jpg has cat
# Filepath /content/dataset/train/dog.4602.jpg has dog
# Filepath /content/dataset/train/dog.1356.jpg has dog
# Filepath /content/dataset/train/dog.3949.jpg has dog
# Filepath /content/dataset/train/dog.12185.jpg has dog
# Filepath /content/dataset/train/dog.4108.jpg has dog
# Filepath /content/dataset/train/cat.608.jpg has cat
# Filepath /content/dataset/train/dog.8369.jpg has dog
# Filepath /content/dataset/train/cat.9340.jpg has cat
# Filepath /content/dataset/train/dog.1652.jpg has dog
# Filepath /content/dataset/train/cat.2108.jpg has cat
# Filepath /content/dataset/train/dog.3296.jpg has dog
# Filepath /content/dataset/train/cat.9360.jpg has cat
# Filepath /content/dataset/train/cat.3765.jpg has cat
# Filepath /content/dataset/train/cat.2882.jpg has cat
# Filepath /content/dataset/train/dog.2421.jpg has dog
# Filepath /content/dataset/train/dog.1402.jpg has dog
# Filepath /content/dataset/train/cat.5038.jpg has cat
# Filepath /content/dataset/train/dog.9956.jpg has dog
# Filepath /content/dataset/train/dog.11890.jpg has dog
# Filepath /content/dataset/train/cat.4761.jpg has cat
# Filepath /content/dataset/train/dog.6759.jpg has dog
# Filepath /content/dataset/train/cat.2499.jpg has cat
# Filepath /content/dataset/train/cat.9278.jpg has cat
# Filepath /content/dataset/train/dog.4071.jpg has dog
# Filepath /content/dataset/train/dog.149.jpg has dog
# Filepath /content/dataset/train/cat.2822.jpg has cat
# Filepath /content/dataset/train/dog.1378.jpg has dog
# Filepath /content/dataset/train/dog.12393.jpg has dog
# Filepath /content/dataset/train/cat.8797.jpg has cat
# Filepath /content/dataset/train/cat.11103.jpg has cat
# Filepath /content/dataset/train/cat.128.jpg has cat
# Filepath /content/dataset/train/dog.10998.jpg has dog
# Filepath /content/dataset/train/dog.10347.jpg has dog
# Filepath /content/dataset/train/dog.2719.jpg has dog
# Filepath /content/dataset/train/dog.3197.jpg has dog
# Filepath /content/dataset/train/cat.9482.jpg has cat
# Filepath /content/dataset/train/cat.11849.jpg has cat
# Filepath /content/dataset/train/cat.3820.jpg has cat
# Filepath /content/dataset/train/cat.11403.jpg has cat
# Filepath /content/dataset/train/dog.6681.jpg has dog
# Filepath /content/dataset/train/dog.8875.jpg has dog
# Filepath /content/dataset/train/dog.4444.jpg has dog
# Filepath /content/dataset/train/cat.7091.jpg has cat
# Filepath /content/dataset/train/cat.5286.jpg has cat
# Filepath /content/dataset/train/dog.9716.jpg has dog
# Filepath /content/dataset/train/dog.10504.jpg has dog
# Filepath /content/dataset/train/cat.3482.jpg has cat
# Filepath /content/dataset/train/cat.1695.jpg has cat
# Filepath /content/dataset/train/dog.11.jpg has dog
# Filepath /content/dataset/train/dog.9761.jpg has dog
# Filepath /content/dataset/train/dog.1869.jpg has dog
# Filepath /content/dataset/train/cat.5270.jpg has cat
# Filepath /content/dataset/train/cat.7846.jpg has cat
# Filepath /content/dataset/train/dog.375.jpg has dog
# Filepath /content/dataset/train/dog.10639.jpg has dog
# Filepath /content/dataset/train/cat.11784.jpg has cat
# Filepath /content/dataset/train/dog.1014.jpg has dog
# Filepath /content/dataset/train/dog.12139.jpg has dog
# Filepath /content/dataset/train/cat.1201.jpg has cat
# Filepath /content/dataset/train/cat.5947.jpg has cat
# Filepath /content/dataset/train/cat.2513.jpg has cat
# Filepath /content/dataset/train/dog.9011.jpg has dog
# Filepath /content/dataset/train/dog.7606.jpg has dog
# Filepath /content/dataset/train/cat.8108.jpg has cat
# Filepath /content/dataset/train/dog.3793.jpg has dog
# Filepath /content/dataset/train/dog.7377.jpg has dog
# Filepath /content/dataset/train/cat.8581.jpg has cat
# Filepath /content/dataset/train/dog.10413.jpg has dog
# Filepath /content/dataset/train/dog.10916.jpg has dog
# Filepath /content/dataset/train/dog.11377.jpg has dog
# Filepath /content/dataset/train/cat.3235.jpg has cat
# Filepath /content/dataset/train/cat.2229.jpg has cat
# Filepath /content/dataset/train/dog.3871.jpg has dog
# Filepath /content/dataset/train/dog.1798.jpg has dog
# Filepath /content/dataset/train/dog.9168.jpg has dog
# Filepath /content/dataset/train/dog.4121.jpg has dog
# Filepath /content/dataset/train/dog.9204.jpg has dog
# Filepath /content/dataset/train/dog.7612.jpg has dog
# Filepath /content/dataset/train/cat.7278.jpg has cat
# Filepath /content/dataset/train/dog.7192.jpg has dog
# Filepath /content/dataset/train/cat.48.jpg has cat
# Filepath /content/dataset/train/dog.8322.jpg has dog
# Filepath /content/dataset/train/cat.4260.jpg has cat
# Filepath /content/dataset/train/dog.6288.jpg has dog
# Filepath /content/dataset/train/cat.3113.jpg has cat
# Filepath /content/dataset/train/cat.6218.jpg has cat
# Filepath /content/dataset/train/dog.11208.jpg has dog
# Filepath /content/dataset/train/cat.11249.jpg has cat
# Filepath /content/dataset/train/dog.3158.jpg has dog
# Filepath /content/dataset/train/cat.8030.jpg has cat
# Filepath /content/dataset/train/dog.504.jpg has dog
# Filepath /content/dataset/train/cat.6254.jpg has cat
# Filepath /content/dataset/train/dog.9106.jpg has dog
# Filepath /content/dataset/train/cat.8146.jpg has cat
# Filepath /content/dataset/train/dog.7669.jpg has dog
# Filepath /content/dataset/train/cat.7985.jpg has cat
# Filepath /content/dataset/train/cat.5548.jpg has cat
# Filepath /content/dataset/train/dog.1480.jpg has dog
# Filepath /content/dataset/train/dog.9862.jpg has dog
# Filepath /content/dataset/train/cat.3648.jpg has cat
# Filepath /content/dataset/train/dog.12412.jpg has dog
# Filepath /content/dataset/train/dog.8743.jpg has dog
# Filepath /content/dataset/train/dog.4841.jpg has dog
# Filepath /content/dataset/train/cat.510.jpg has cat
# Filepath /content/dataset/train/dog.12453.jpg has dog
# Filepath /content/dataset/train/dog.7390.jpg has dog
# Filepath /content/dataset/train/cat.2732.jpg has cat
# Filepath /content/dataset/train/cat.5052.jpg has cat
# Filepath /content/dataset/train/cat.1983.jpg has cat
# Filepath /content/dataset/train/cat.2296.jpg has cat
# Filepath /content/dataset/train/dog.10412.jpg has dog
# Filepath /content/dataset/train/cat.1974.jpg has cat
# Filepath /content/dataset/train/cat.2062.jpg has cat
# Filepath /content/dataset/train/cat.10898.jpg has cat
# Filepath /content/dataset/train/cat.215.jpg has cat
# Filepath /content/dataset/train/cat.943.jpg has cat
# Filepath /content/dataset/train/dog.5005.jpg has dog
# Filepath /content/dataset/train/dog.7556.jpg has dog
# Filepath /content/dataset/train/dog.5441.jpg has dog
# Filepath /content/dataset/train/dog.11748.jpg has dog
# Filepath /content/dataset/train/cat.1392.jpg has cat
# Filepath /content/dataset/train/dog.10940.jpg has dog
# Filepath /content/dataset/train/cat.1568.jpg has cat
# Filepath /content/dataset/train/dog.7939.jpg has dog
# Filepath /content/dataset/train/dog.4148.jpg has dog
# Filepath /content/dataset/train/cat.4402.jpg has cat
# Filepath /content/dataset/train/cat.2946.jpg has cat
# Filepath /content/dataset/train/cat.5189.jpg has cat
# Filepath /content/dataset/train/dog.9944.jpg has dog
# Filepath /content/dataset/train/cat.3831.jpg has cat
# Filepath /content/dataset/train/cat.1368.jpg has cat
# Filepath /content/dataset/train/dog.10308.jpg has dog
# Filepath /content/dataset/train/cat.4391.jpg has cat
# Filepath /content/dataset/train/cat.4072.jpg has cat
# Filepath /content/dataset/train/cat.9854.jpg has cat
# Filepath /content/dataset/train/dog.6314.jpg has dog
# Filepath /content/dataset/train/dog.1208.jpg has dog
# Filepath /content/dataset/train/dog.9696.jpg has dog
# Filepath /content/dataset/train/dog.6155.jpg has dog
# 12500 25000

# %%
# !pip3 install cnn_finetune
# Out:
# Collecting cnn_finetune
#   Downloading https://files.pythonhosted.org/packages/e4/63/03a442d31401c43fc17a814f22bd7c39ab8f13f42a6b2467ca0d0d042b3a/cnn_finetune-0.6.0.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from cnn_finetune) (1.5.0+cu101)
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from cnn_finetune) (0.6.0+cu101)
# Collecting pretrainedmodels>=0.7.4
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#      |████████████████████████████████| 61kB 3.7MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from cnn_finetune) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from cnn_finetune) (4.38.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->cnn_finetune) (1.18.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->cnn_finetune) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->cnn_finetune) (7.0.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from munch->pretrainedmodels>=0.7.4->cnn_finetune) (1.12.0)
# Building wheels for collected packages: cnn-finetune, pretrainedmodels
#   Building wheel for cnn-finetune (setup.py) ... done
#   Created wheel for cnn-finetune: filename=cnn_finetune-0.6.0-cp36-none-any.whl size=11432 sha256=3104033138eb4988d9eb1c37446e932c2145351dea999a571e45821ca02b3ee0
#   Stored in directory: /root/.cache/pip/wheels/12/4f/29/32978e72b606c5f51b6bd10117814deb46c6b63230eef49381
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60962 sha256=de393d05932b217d5100bad546a4b60fa6a37ed37d0efa4ad28e8a974d9f96af
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built cnn-finetune pretrainedmodels
# Installing collected packages: munch, pretrainedmodels, cnn-finetune
# Successfully installed cnn-finetune-0.6.0 munch-2.5.0 pretrainedmodels-0.7.4

# %%
import numpy as np
import csv

with open('train_all.csv', mode='w+') as train_file:
    writer = csv.writer(train_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    i = 0
    class_label = 0

    for i in range(0,25000):

        if i>12499:
            class_label = 1

        writer.writerow(['{}.png'.format(i),'{}'.format(class_label)])

# %%
from __future__ import print_function, division

import matplotlib
# matplotlib.use('agg')

import matplotlib.pyplot as plt
import argparse
import torch
import torch.nn as nn
import pandas as pd
from skimage import io, transform
from skimage.transform import rescale, resize
import torch.nn.functional as F     
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import torch.utils.data as data_utils
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import warnings
import math
import sys

import numpy as np
import torchvision
from torchvision import datasets, models, transforms, utils
import time
import os
from os import path
from cnn_finetune import make_model

import random
import time

warnings.filterwarnings("ignore")

# parser = argparse.ArgumentParser(description='cnn_finetune')

# parser.add_argument('--batch-size', type=int, default=2, metavar='N',
#                     help='input batch size for training (default: 32)')

# parser.add_argument('--test-batch-size', type=int, default=4, metavar='N',
#                     help='input batch size for testing (default: 64)')

# parser.add_argument('--epochs', type=int, default=200, metavar='N',
#                     help='number of epochs to train (default: 100)')

# parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
#                     help='learning rate (default: 0.01)')


PATH = 'resnet50.pt'

thresh = 0.05

rdeftrain = 0
rdeftest = 0

beginning = time.time()

epno = 0
use_gpu=0

tta = []
toa = []

# args = parser.parse_args()

if torch.cuda.is_available():
    device = torch.device("cuda")
    use_gpu=1 
    print ("CUDA Available")

epochs = 4
lr = 0.7

batch_size = 64
batch_size_test = 64
epochs_num = epochs

print ("Batch size is {0}".format(batch_size))
print ("Batch size test is {0}".format(batch_size_test))
print ("Epoch size is {0}".format(epochs_num))
print ("This is nn7. name is 1")

model = make_model('resnet50', num_classes=2, pretrained=False, input_size=(224, 224))


transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    # transforms.Normalize(
    #     mean=model.original_model_info.mean,
    #     std=model.original_model_info.std),
    # transforms.ToPILImage(),
])


# frun = open("values_running.csv","w+")

class Dataloader(Dataset):

    def __init__(self, csv_file, root_dir, transform=None):

        self.data = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir,
                                self.data.iloc[idx, 0])

        image = io.imread(img_name)

        # print(img_name)

        # image = resize(image,(250,250), anti_aliasing=True)

        # image = torchvision.transforms.ToPILImage(image)

        # image = torchvision.transforms.functional.to_pil_image(image)
        # image = torchvision.transforms.functional.resize(image,(225,225))

        # # image = torchvision.transforms.ToTensor(image)
        # image = torchvision.transforms.functional.to_tensor(image)

        # image = image.reshape([image.shape[2], image.shape[1], image.shape[0]])

        # image = torch.FloatTensor(image)

        class_label = self.data.iloc[idx, 1]

        if class_label==0:
            class_label = np.array([0])
        else:
            class_label = np.array([1])

        class_label = class_label.astype('long').reshape(1, 1)

        class_label = torch.LongTensor(class_label)

        sample = {'image': image, 'class_label': class_label}

        if self.transform:
            image1 = self.transform(sample['image'])
            image1 = torch.FloatTensor(image1)
            sample = {'image': image1, 'class_label': class_label}

        # sample = data_utils.TensorDataset(sample)

        return sample
#################################################

# class_label_frame = pd.read_csv("/users/v.dorbala/me/vpscmu.csv")

# n = 65
# img_name = class_label_frame.iloc[n, 0]
# class_label = class_label_frame.iloc[n, 1:].as_matrix()
# class_label = class_label.astype('float').reshape(-1, 1)

# print('Image name: {}'.format(img_name))
# print('class_label shape: {}'.format(class_label.shape))
# print('class_label value: {}'.format(class_label[:1]))
# model_conv = torchvision.models.alexnet(pretrained=True)

# num_features = 1

# num_ftrs = model_conv.classifier[6].in_features
# model_conv.classifier[6] = nn.Linear(num_ftrs, num_features)

# for param in model_conv.classifier[6].parameters():
#   param.requires_grad = True

# print(model)

model_ft = model.to(device)

if use_gpu == 1:
    model_ft = nn.DataParallel(model_ft).cuda()

if path.exists(PATH):
    model_ft.load_state_dict(torch.load(PATH))

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(model_ft.parameters(), lr=lr, momentum=0.9, weight_decay=0.005)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

trainset = Dataloader(csv_file='/content/train_all.csv', root_dir='/content/train_renamed',transform=transform)

# testset = Dataloader(csv_file='test_all.csv', root_dir='./train_renamed',transform=transform)
# print ("Size of the dataset is {}".format(len(trainset)))
#transforms.Compose([Rescale(256),RandomCrop(224),ToTensor()]))

# trsize = int(len(trainset)*2/3)
# tesize = len(trainset) - trsize
# print (trsize,tesize,len(trainset))

validation_split = 0.1
shuffle_dataset = True

nums = [x for x in range(10,100)]
random.shuffle(nums)

random_seed=nums[int(time.time())%90]

# Creating data indices for training and validation splits:
dataset_size = len(trainset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

# trainset, testset = torch.utils.data.random_split(trainset,[trsize,tesize])
# print (len(trainset),len(testset))
# train_sampler = SubsetRandomSampler(trainset)
# test_sampler = SubsetRandomSampler(testset)

# print (type(train_sampler))

# trainset = Dataloader(csv_file='trainall.csv', root_dir='/users/v.dorbala/me/fin3/',transform=transform)#transforms.Compose([Rescale(256),RandomCrop(224),ToTensor()]))

train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          num_workers=2,sampler=train_sampler)
# testset = Dataloader(csv_file='vps1.csv', root_dir='/users/v.dorbala/me/testfin/',transform=transform)#transforms.Compose([Rescale(256),RandomCrop(224),ToTensor()]))

test_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size_test,
                                        num_workers=2,sampler=valid_sampler)


# Helper function to show a batch
# def show_landmarks_batch(sample_batched):
#     """Show image with landmarks for a batch of samples."""
#     images_batch, landmarks_batch = \
#             sample_batched['image'], sample_batched['class_label']
#     batch_size = len(images_batch)
#     im_size = images_batch.size(2)

#     grid = utils.make_grid(images_batch)
#     plt.imshow(grid.numpy().transpose((1, 2, 0)))

#     # for i in range(batch_size):
#     #     plt.scatter(landmarks_batch[i, :, 0].numpy() + i * im_size,
#     #                 landmarks_batch[i, :, 1].numpy(),
#     #                 s=10, marker='.', c='r')

# for i_batch, sample_batched in enumerate(train_loader):
#     print(i_batch, sample_batched['image'].size(),
#           sample_batched['class_label'].size())

#     # observe 4th batch and stop.
#     if i_batch == 3:
#         plt.figure()
#         show_landmarks_batch(sample_batched)
#         plt.axis('off')
#         plt.title('Train Dataset Batch')
#         plt.ioff()
#         plt.show()
#         break


# for i_batch, sample_batched in enumerate(test_loader):
#     print(i_batch, sample_batched['image'].size(),
#           sample_batched['class_label'].size())

#     # observe 4th batch and stop.
#     if i_batch == 3:
#         plt.figure()
#         show_landmarks_batch(sample_batched)
#         plt.axis('off')
#         plt.ioff()
#         plt.title('Test Dataset Batch')
#         plt.show()
#         break
# testset = torchvision.datasets.CIFAR10(root='./Cifar10', train=False,
#                                        download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
#                                          shuffle=False, num_workers=2)

trainlossarr = []
testlossarr = []

trainrsqarr = []
testrsqarr = []
# def restart_program():

#     os.execl(sys.executable, os.path.abspath(__file__), *sys.argv)
#     python = sys.executable
#     os.execl(python, python, * sys.argv)


def train(epoch):
    global rdeftrain
    since = time.time()
    total_loss = 0
    total_size = 0
    traintargetarr = []
    trainoutputarr = []
    model_ft.train()

    print ("Epoch number is {}".format(epoch))

    for batch_idx, values in enumerate(train_loader):
        
        # print("Values are size {0}, {1}, {2}".format(len(values),(values['image'].shape),(values['class_label'].shape)))

        data, target = values['image'], values['class_label']

        # print("Data type is {0}, {1}.".format(data,data.shape))

        target = target.view(-1,1)

        # print("Now target is {0}".format(target)) 

        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()

        output = model_ft(data)

        # print ("Target is {0}. \n Output is {1}.".format(target.numpy(),output.numpy()))

        # print(batch_idx)

        # rsq = r2_score(target.numpy(),output.numpy())
        
        traintargetarr.append(target.tolist())
        trainoutputarr.append(output.tolist())


        loss = criterion(output, target.squeeze())

        total_loss += loss.item()

        total_size += 1

        # print ("Data size is {}. \n Total size is {}".format(data.size(0),total_size))

        
        loss.backward()
        
        optimizer.step()

        # if batch_idx % args.log_interval == 10:
        #     print('Train Epoch: {} [{}/{} ({:.0f}%)]\tAverage loss: {}'.format(
        #         epoch, batch_idx * len(data), len(train_loader.dataset),
        #         100. * batch_idx / len(train_loader), total_loss / total_size))
        # if math.isnan(total_loss) == True:
        #     sys.exit('Loss has gone to NaN. Doubling the batch size.')
            # restart_program()

        print((total_loss/total_size)*100)

    tta = np.array(traintargetarr)
    tta = [val for sublist in traintargetarr for val in sublist]
    tta = np.array(tta)
    toa = np.array(trainoutputarr)
    toa = [val for sublist in trainoutputarr for val in sublist]
    toa = np.array(toa)
    # print (tta.flatten(),toa.flatten())
    # rsqtrain = r2_score(tta.flatten(),toa.flatten())

    # vconst = 0.2
    # pinv = (-1)*(np.linalg.pinv(Jw))
    # fmat = le + Jv*vconst
    # w = pinv*(fmat)

    # print ("RSQtrain is {}".format(rsqtrain))
    trainlossarr.append((total_loss/total_size))
    # trainrsqarr.append(rsqtrain)
    # if rsqtrain>rdeftrain:
    #     rdeftrain = rsqtrain
    #     # model_ft_best = copy.deepcopy(model_ft)
    #     torch.save(model_ft.state_dict(), PATH)
    # frun.write("{},".format(total_loss/total_size))
    # time_elapsed = time.time() - since
    # print('Training complete in {:.0f}m {:.0f}s'.format(
    #     time_elapsed // 60, time_elapsed % 60))


def test():
    global tta,toa,rdeftest
    # model_ft.load_state_dict(torch.load(PATH))
    model_ft.eval()
    test_loss = 0
    total_loss = 0
    total_size = 0

    testtargetarr = []
    testoutputarr = []

    with torch.no_grad():
        for batch_idx, values in enumerate(test_loader):

            data, target = values['image'], values['class_label']

            target = target.view(-1,1)

            data, target = data.to(device), target.to(device)

            # print (data.size())

            output = model_ft(data)

            # print ("Test Target is {0}. \n Output is {1}.".format(target,output))
            # print ("Target type is {0}. \n Output type is {1}.".format(target.type,output.type))
            # print ("Target shape is {0}. \n Output shape is {1}.".format(target.shape,output.shape))

            loss = criterion(output, target.squeeze())

            total_loss += loss.item()

            total_size += 1
        
            testtargetarr.append(target.tolist())
            testoutputarr.append(output.tolist())

            print ("Loss is {}".format(loss*100))
            # pred = output.data.max(1, keepdim=True)[0]

            # correct += pred.eq(target.data.view_as(pred)).long().cpu().sum().item()

    tta = np.array(testtargetarr)
    tta = [val for sublist in testtargetarr for val in sublist]
    tta = np.array(tta)
    toa = np.array(testoutputarr)
    toa = [val for sublist in testoutputarr for val in sublist]
    toa = np.array(toa)

    # rsqtest = r2_score(tta.flatten(),toa.flatten())
    # print ("RSQtest is {}\n".format(rsqtest))

    # test_loss /= len(test_loader.dataset)    
    testlossarr.append(total_loss/total_size)
    # testrsqarr.append(rsqtest)
    # frun.write("{},".format(test_loss))



for epoch in range(1, epochs + 1):
    train(epoch)
    test()
    print ("\n Epoch number is {}.".format(epoch))

    if epoch % 10 == 0:
        print("Loss at epoch {} is {}%".format(epoch,100*(fincorr/epoch)))

# torch.save(model_ft.state_dict(), PATH)

time_elapsed = time.time() - beginning
print('Process complete in {:.0f}m {:.0f}s'.format(
    time_elapsed // 60, time_elapsed % 60))


# trace = dict(x=[1:args.epochs], y=testlossarr, mode="markers+lines", type='custom',
#              marker={'color': 'red', 'symbol': 104, 'size': "10"}, name='1st Trace')

trainlossarr = np.array(trainlossarr)
testlossarr = np.array(testlossarr)

trainrsqarr = np.array(trainrsqarr)
testrsqarr = np.array(testrsqarr)

file = open("resnet50.csv","w+")

file.write("Train values are \n")

for i in range(len(trainlossarr)):
    file.write("{},".format(trainlossarr[i]))

file.write("\n Test values are \n")

for i in range(len(testlossarr)):
    file.write("{},".format(testlossarr[i]))

# file.write("\n Train R-squared values are \n")

# for i in range(len(trainrsqarr)):
#     file.write("{},".format(trainrsqarr[i]))

# file.write("\n Test R-squared values are \n")

# for i in range(len(testrsqarr)):
#     file.write("{},".format(testrsqarr[i]))

file.close()

t = np.arange(0,epochs_num,1)

plt.plot(t,trainlossarr,t,testlossarr)
plt.xlabel("Epochs")
plt.ylabel("Loss value")
plt.title("Train and test losses (Normal)")
plt.show()
# print ("Overall Loss on test data is {}%)".format(test_loss))


# viz.line(X=None, Y=None, win=win, name='delete this', update='remove')


# layout = dict(title="Testing Loss", xaxis={'Epoch': 'x1'}, yaxis={'Loss': 'x2'})

# vis._send({'data': win, 'layout': layout, 'win': 'mywin'})
# resize = [224,224]    
# data_transforms = {
#         'test': transforms.Compose([
#             #Higher scale-up for inception
#             transforms.Resize(max(resize)),
#             #transforms.RandomHorizontalFlip(),
#             #transforms.CenterCrop(max(resize)),
#             transforms.ToTensor(),
#             transforms.Normalize([0.620, 0.446, 0.594], [0.218, 0.248, 0.193])
#         ]),
#     }

# image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
#                                           data_transforms[x])
#                   for x in ['train', 'test']}
# dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
#                                              shuffle=True, num_workers=4)
#               for x in ['train', 'test']}
# dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}

# class_names = image_datasets['train'].classes

# def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
#     since = time.time()

#     best_model_wts = copy.deepcopy(model.state_dict())
#     best_acc = 0.0

#     for epoch in range(num_epochs):
#         print('Epoch {}/{}'.format(epoch, num_epochs - 1))
#         print('-' * 10)

#         # Each epoch has a training and validation phase
#         for phase in ['train', 'test']:
#           print (phase)
#             if phase == 'train':
#                 scheduler.step()
#                 model.train()  # Set model to training mode
#             else:
#                 model.test()   # Set model to evaluate mode

#             running_loss = 0.0
#             running_corrects = 0

#             # Iterate over data.
#             for inputs, labels in dataloaders[phase]:
#                 inputs = inputs.to(device)
#                 labels = labels.to(device)

#                 # zero the parameter gradients
#                 optimizer.zero_grad()

#                 # forward
#                 # track history if only in train
#                 with torch.set_grad_enabled(phase == 'train'):
#                     outputs = model(inputs)
#                     _, preds = torch.max(outputs, 1)
#                     loss = criterion(outputs, labels)

#                     # backward + optimize only if in training phase
#                     if phase == 'train':
#                         loss.backward()
#                         optimizer.step()

#                 # statistics
#                 running_loss += loss.item() * inputs.size(0)
#                 running_corrects += torch.sum(preds == labels.data)

#             epoch_loss = running_loss / dataset_sizes[phase]
#             epoch_acc = running_corrects.double() / dataset_sizes[phase]

#             print('{} Loss: {:.4f} Acc: {:.4f}'.format(
#                 phase, epoch_loss, epoch_acc))

#             # deep copy the model
#             if phase == 'val' and epoch_acc > best_acc:
#                 best_acc = epoch_acc
#                 best_model_wts = copy.deepcopy(model.state_dict())

#         print()

#     time_elapsed = time.time() - since
#     print('Training complete in {:.0f}m {:.0f}s'.format(
#         time_elapsed // 60, time_elapsed % 60))
#     print('Best val Acc: {:4f}'.format(best_acc))

#     # load best model weights
#     model.load_state_dict(best_model_wts)
#     return model

# model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
#                        num_epochs=25)
# Out:
# CUDA Available
# Batch size is 64
# Batch size test is 64
# Epoch size is 4
# This is nn7. name is 1
# Epoch number is 1
# 70.23606896400452
# 1696.3376313447952
# 10831.033152341843
# 12168.153251707554
# 10109.398738145828
# 8533.599735299747
# 7364.851594822747
# 6514.144317060709
# 5804.505567418205
# 5231.653224229813
# 4797.228874943473
# 4415.772919853529
# 4081.9144615760215
# 3811.186812605177
# 3563.8572859764095
# 3346.0109166800976
# 3167.2688379007227
# 3001.3579421573218
# 2847.467040074499
# 2714.7353413701057
# 2588.664898134413
# 2478.799632191658
# 2375.9771603605022
# 2280.2131046851473
# 2193.4260358810425
# 2111.6697258674185
# 2035.9911697882194
# 1968.533687080656
# 1902.937983849953
# 1841.7349265019097
# 1785.9741962725118
# 1733.5843870416284
# 1683.2876987529523
# 1635.7628327958726
# 1591.793601172311
# 1549.4417127635745
# 1510.3773216943484
# 1472.816020564029
# 1437.1028108474536
# 1403.4766310453415
# 1370.925790362242
# 1341.3612557309013
# 1312.4495586683583
# 1284.4530796462839
# 1257.6674649450513
# 1232.173005523889
# 1207.44159234331
# 1183.7096157173314
# 1161.1191653475469
# 1139.33536362648
# 1118.3764872597712
# 1098.1760293245316
# 1078.8302846674649
# 1060.2303153938717
# 1042.201700102199
# 1024.9111511877604
# 1008.2135184815055
# 992.0354144326571
# 976.439709178472
# 961.3252019882202
# 946.7518246564708
# 932.6175259967004
# 918.9444031034197
# 905.6504202075303
# 892.9000226350931
# 880.4122465126442
# 868.310835290311
# 856.5436379874453
# 845.1468565325806
# 834.081392969404
# 823.3551973188428
# 812.9315180910958
# 802.7276924211685
# 792.8391754627228
# 783.2383881409963
# 773.8238779337782
# 764.6992359068487
# 755.8111720360242
# 747.1349489085281
# 738.6753925681114
# 730.4369076534554
# 722.3725840812776
# 714.5049506641296
# 706.8167670142083
# 699.3045490629532
# 692.0144221810407
# 684.8664544094568
# 677.8563596308231
# 671.0103909621079
# 664.3272196584278
# 657.79352751407
# 651.3969731719598
# 645.1436531159185
# 639.0197787513125
# 633.0353416894612
# 627.1632603059213
# 621.4135670170341
# 615.8017156683669
# 610.2737823520043
# 604.8786572217941
# 599.5826080293939
# 594.3985789429908
# 589.303402646074
# 584.3507332870593
# 579.4593054339999
# 574.628117568088
# 569.9847643063447
# 565.3997687829866
# 560.8684179432895
# 556.4091012694619
# 552.0521866308676
# 547.7562974074057
# 543.5212296194734
# 539.3581119022872
# 535.2782914949499
# 531.2801459739948
# 527.3300606470841
# 523.4517632399575
# 519.6335948314987
# 515.8905308445295
# 512.196852993374
# 508.59728279660953
# 505.03912064118117
# 501.53762876026093
# 498.0817101955414
# 494.70092067642815
# 491.363714623639
# 488.08486028574407
# 484.8436277966167
# 481.646941120808
# 478.50484179176453
# 475.44658680756885
# 472.3901693085979
# 469.38078314510744
# 466.4158633461705
# 463.4954532717957
# 460.6370197160401
# 457.7991244585617
# 455.00576165940265
# 452.2470240507807
# 449.5323533707476
# 446.85345783200063
# 444.20643423820707
# 441.6056290268898
# 439.01265140237473
# 436.5271512367954
# 434.040509316386
# 431.5730066718282
# 429.13724996099535
# 426.7594969272613
# 424.40047749620396
# 422.0687871308703
# 419.7723489181668
# 417.5002454937278
# 415.2851175108264
# 413.0705763896306
# 410.87471649145624
# 408.7176119979424
# 406.57714669059663
# 404.46921877563
# 402.37900759122385
# 400.31175933502334
# 398.323307044667
# 396.33676409721375
# 394.35561097029483
# 392.4219829131322
# 390.507683389915
# 388.6223142700536
# 386.7399170201206
# 384.87723217290994
# 383.0703295810878
# 381.2856916771379
# 379.496151174424
# 377.71351621753865
# 375.9636818681444
# 374.24648793583566
# 372.553565913001
# 370.8512741863058
# 369.16729374970805
# 367.50331001149283
# 365.879626366315
# 364.27115143000424
# 362.65830049097866
# 361.06084672653157
# 359.49412072027053
# 357.9585377888013
# 356.44275667195654
# 354.9154822496658
# 353.40512685044104
# 351.9014289190895
# 350.3959254444582
# 348.97552160546184
# 347.5594246325715
# 346.12457042502376
# 344.71006414829156
# 343.2893486351383
# 341.93151971410373
# 340.5848395041745
# 339.22151596701923
# 337.8706914782524
# 336.5349879312278
# 335.2268631800567
# 333.9274809865529
# 332.63538517788345
# 331.3487857725562
# 330.0353979890786
# 328.84089817171514
# 327.6630043410338
# 326.43842517474053
# 325.21213267530715
# 323.99952468148905
# 322.8168383803008
# 321.6270304061997
# 320.4690399013947
# 319.29529811060706
# 318.1424863360546
# 316.9954230983136
# 315.8838760688764
# 314.7797311277694
# 313.6668840321628
# 312.56068893687217
# 311.4675710867117
# 310.38168911976663
# 309.30608777063236
# 308.2323262691498
# 307.1872540807302
# 306.1437864398116
# 305.10708632176386
# 304.08052966063724
# 303.0494059687075
# 302.0611792415767
# 301.060444373509
# 300.06586333712795
# 299.0781557356191
# 298.1096672758143
# 297.16149209919627
# 296.1950962302051
# 295.2426128026818
# 294.2988416390439
# 293.36481263240177
# 292.43663227904386
# 291.51970997822184
# 290.6028726218659
# 289.6964872469668
# 288.79560451118317
# 287.9018365367641
# 287.015106610441
# 286.13418607461836
# 285.2704802430777
# 284.4037701129913
# 283.54760341910253
# 282.6971572779474
# 281.85434612360865
# 281.0182450559195
# 280.1880701616699
# 279.36415560543537
# 278.5461186898822
# 277.73356506990837
# 276.9328692244747
# 276.1313133285596
# 275.3437852494105
# 274.55714968324617
# 273.7788556873118
# 273.01262903845674
# 272.24835856905526
# 271.4828148148114
# 270.7259110073918
# 269.97208955572614
# 269.2161109367711
# 268.49359472592676
# 267.7922411818346
# 267.066607514725
# 266.342898450055
# 265.6210033127861
# 264.89266018434006
# 264.2050904208335
# 263.5244308826295
# 262.87720299881994
# 262.1847014273367
# 261.50389026318277
# 260.9110467162421
# 260.2786230702772
# 259.62551634219005
# 258.9564903731077
# 258.29102177368964
# 257.7079335292736
# 257.11630998172825
# 256.47836530374155
# 255.83091452459973
# 255.19637338046368
# 254.5987017785561
# 253.9719969850697
# 253.34796964511938
# 252.72134141046175
# 252.1052637342679
# 251.48369716228666
# 250.868240610919
# 250.26409107966708
# 249.66018473025548
# 249.05858967701593
# 248.4615007904281
# 247.87061569706492
# 247.28449789604338
# 246.69860505351892
# 246.11709803831383
# 245.54114037869024
# 244.97606847495908
# 244.4067383934925
# 243.84274831867526
# 243.27936870436514
# 242.72476160641267
# 242.1705644482221
# 241.61831462345185
# 241.06972724389118
# 240.53046031603736
# 239.98725052121318
# 239.44528416880297
# 238.91682574209176
# 238.38558970573928
# 237.85664912313226
# 237.32186654275077
# 236.8033323784052
# 236.30274080270587
# 235.79126631404148
# 235.27668303709763
# 234.76750874446216
# 234.2603281550451
# 233.76691299604207
# 233.2722583983807
# 232.7789762164607
# 232.2857460406612
# 231.7960144884615
# 231.30603335999155
# 230.8224353961602
# 230.35520587394487
# 229.88422442050208
# 229.41440034337143
# 228.94073278593595
# 228.46344023679208
# 228.0085220582345
# 227.54911852022767
# 227.08682318528494
# 226.6236951677862
# 226.16681089234905
# 225.70301252862683
# 225.2747293669364
# 224.82720570536787
# 224.3831588447779
# 223.94060381504048
# 223.50273443971363
# 223.09571633651385
# 222.67699075693432
# Loss is 69.42877960205078
# Loss is 69.4792709350586
# Loss is 69.58029174804688
# Loss is 69.12576293945312
# Loss is 69.52977752685547
# Loss is 69.17625427246094
# Loss is 69.12574768066406
# Loss is 69.42877960205078
# Loss is 69.47927856445312
# Loss is 69.52977752685547
# Loss is 69.22675323486328
# Loss is 69.32777404785156
# Loss is 69.7317886352539
# Loss is 69.12574005126953
# Loss is 69.37826538085938
# Loss is 69.37826538085938
# Loss is 69.37826538085938
# Loss is 69.42876434326172
# Loss is 69.32776641845703
# Loss is 69.27725982666016
# Loss is 69.3782730102539
# Loss is 69.42876434326172
# Loss is 68.97422790527344
# Loss is 69.1762466430664
# Loss is 69.17625427246094
# Loss is 69.42877197265625
# Loss is 69.42877960205078
# Loss is 69.3782730102539
# Loss is 69.42877197265625
# Loss is 69.27725982666016
# Loss is 69.12574768066406
# Loss is 69.3277587890625
# Loss is 69.58028411865234
# Loss is 69.32777404785156
# Loss is 69.47927856445312
# Loss is 69.22676086425781
# Loss is 69.27725982666016
# Loss is 69.58028411865234
# Loss is 69.12574005126953
# Loss is 68.78907775878906
#
#  Epoch number is 1.
# Epoch number is 2
# 69.37826871871948
# 70.19891738891602
# 73.51955970128378
# 72.96395003795624
# 71.81144833564758
# 71.33601407210031
# 71.02268253053937
# 70.75662314891815
# 70.53626908196343
# 70.40528416633606
# 70.30133388259195
# 70.39931416511536
# 70.33044787553641
# 70.22590935230255
# 70.38131634394328
# 70.69638296961784
# 70.7764720215517
# 70.71869174639383
